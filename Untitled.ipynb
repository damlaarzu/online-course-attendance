# %%
import pandas as pd

# %%
print("hello world")
# Out:
# hello world

# %%
df1=pd.read_csv("C:\Users\90506\Downloads\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
# Out:
#   Cell In[3], line 1
#     df1=pd.read_csv("C:\Users\90506\Downloads\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df1=pd.read_xlsx("C:\Users\90506\Downloads\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
# Out:
#   Cell In[4], line 1
#     df1=pd.read_xlsx("C:\Users\90506\Downloads\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df1=pd.read_xlsx("ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1=pd.read_xlsx("ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
df1=pd.read_csv("ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1=pd.read_csv("ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx'

# %%
df1=pd.read_csv("21martyoklama.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1=pd.read_csv("21martyoklama.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '21martyoklama.csv'

# %%
df1=pd.read_csv("21martyoklama.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1=pd.read_csv("21martyoklama.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '21martyoklama.csv'

# %%
df=pd.read_csv("21martyoklama.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df=pd.read_csv("21martyoklama.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '21martyoklama.csv'

# %%
df=pd.read_csv("ilkyoklama.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df=pd.read_csv("ilkyoklama.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ilkyoklama.csv'

# %%
df = pd.read_excel('ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_excel('ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx'

# %%
df = pd.read_excel("21martyoklama.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_excel("21martyoklama.csv")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '21martyoklama.csv'

# %%
df = pd.read_excel(""C:\Users\90506\Desktop\21martyoklama.csv"")
# Out:
#   Cell In[14], line 1
#     df = pd.read_excel(""C:\Users\90506\Desktop\21martyoklama.csv"")
#                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df= pd.read_excel("C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
# Out:
#   Cell In[15], line 1
#     df= pd.read_excel("C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df= pd.read_excel(r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df= pd.read_excel(r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)
#     539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)
#     550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl.metadata
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 217.9 kB/s eta 0:00:02
#    --------- ----------------------------- 61.4/250.9 kB 328.2 kB/s eta 0:00:01
#    ----------------- -------------------- 112.6/250.9 kB 547.6 kB/s eta 0:00:01
#    ----------------------- -------------- 153.6/250.9 kB 612.6 kB/s eta 0:00:01
#    ---------------------------------- --- 225.3/250.9 kB 724.0 kB/s eta 0:00:01
#    -------------------------------------- 250.9/250.9 kB 771.4 kB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
[notice] To update, run: python.exe -m pip install --upgrade pip
# Out:
#   Cell In[18], line 1
#     [notice] To update, run: python.exe -m pip install --upgrade pip
#              ^
# SyntaxError: invalid syntax

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\90506\appdata\local\programs\python\python312\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/f4/ab/e3c039b5ddba9335bd8f82d599eb310de1d2a2db0411b8d804d507405c74/pip-24.1.1-py3-none-any.whl.metadata
#   Downloading pip-24.1.1-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.1.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 660.6 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.8 MB 812.7 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.8 MB 901.1 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.8 MB 1.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.8 MB 1.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.8 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.8 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 836.7 kB/s eta 0:00:02
#    -------------- ------------------------- 0.7/1.8 MB 1.1 MB/s eta 0:00:02
#    --------------- ------------------------ 0.7/1.8 MB 1.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 0.9/1.8 MB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.8 MB 1.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.8 MB 1.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.2/1.8 MB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.8 MB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 1.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 1.1 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-24.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df= pd.read_excel(r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx")

# %%
df
# Out:
#     Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
# 0      23466           ABDULLAH ASLAN                      50         NaN
# 1      23582                 ALİ DOST                      50         NaN
# 2      23451             AYLİN YILDIZ                      50         NaN
# 3      23457            AYSU YILDIRIM                      50         NaN
# 4      23570           BAVER AYYILDIZ                      50         NaN
# 5      23469               BULUT AZAK                      38         NaN
# 6      23596         CEMAL CAN ARSLAN                      42         NaN
# 7      23471             DİLAN ERTUNÇ                      50         NaN
# 8      23459              ENGİN AYVAT                      50         NaN
# 9      23198              ERDAL ŞAHAN                       0         NaN
# 10     23458           ERTUĞRUL AYDIN                      46         NaN
# 11     23455             FADİME SAÇAR                      50         NaN
# 12     23450               FARUK OKAY                      50         NaN
# 13     23193          FATİH KARADİKEN                      46         NaN
# 14     19031             FURKAN ŞAHİN                      50         NaN
# 15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
# 16     23462            HAKAN ERTİNGÜ                      50         NaN
# 17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
# 18     23472            İBRAHİM YAŞAR                      40         NaN
# 19     23456              İSHAK ÖZBEK                      50         NaN
# 20     23448        KAAN MAHMUT MACAR                      50         NaN
# 21     23196              KÜBRA GÖKÇE                      50         NaN
# 22     23467            MERVE NUR KUŞ                      50         NaN
# 23     23465             MESUT TEKELİ                      46         NaN
# 24     23470       MİRZA MEHMET YÜCEL                      50         NaN
# 25     23581      MUHAMMET EMİN KESİK                      50         NaN
# 26     23330       MUHAMMET KARADUMAN                      50         NaN
# 27     23449   MUHAMMET LÜTFİ BAŞBOĞA                      46         NaN
# 28     23138        MUHAMMET YILDIRIM                      50         NaN
# 29     23464            MUKADDER KENT                      50         NaN
# 30     23452         MUSA OZAN PATACI                      50         NaN
# 31     23136              OKTAY AYANA                      46         NaN
# 32     23453            ÖMER BOSTANCI                      30         NaN
# 33     23195            ÖMER YILDIRIM                      50         NaN
# 34     23132              ÖZCAN ÇAKIR                      50         NaN
# 35     23463            SERDAR YAZICI                      50         NaN
# 36     23460         SERHAT ÇETİNKAYA                      50         NaN
# 37     23194               SEYDİ SARI                      50         NaN
# 38     23473            ŞAHİN TAŞKAYA                      38         NaN
# 39     23580                ŞEYDA ÖRS                      50         NaN
# 40     23197                TANER HAN                      50         NaN
# 41     23454          TANER HANIMOĞLU                      46         NaN
# 42     23461          TARIK YİĞİTBAŞI                      50         NaN
# 43     23273              TUĞÇE DOĞAN                      50         NaN
# 44     23134              EMRAH KÜÇÜK                       0         NaN
# 45     23135           FETHİYE YILMAZ                       0         NaN
# 46     23272             ÇETİN ÇELEBİ                       0         NaN
# 47     23332        ALİ İHSAN DESTİCİ                       0         NaN
# 48     23587                 OKAN GÖK                       0         NaN
# 49     23588              TURGAY KAYA                       0         NaN
# 50     23340                 ALİ İĞDE                       0         NaN
# 51     19781               ALİ DÜNDAR                       0         NaN
#
#             Unnamed: 4
# 0                  NaN
# 1                  NaN
# 2   DERS SÜRESİ 51 DK.
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45                 NaN
# 46                 NaN
# 47                 NaN
# 48                 NaN
# 49                 NaN
# 50                 NaN
# 51                 NaN

# %%
df.drop(columns=["Unnamed: 3","Unnamed: 4"])
# Out:
#     Sicil No                 Ad Soyad  Oturum Süresi (Dakika)
# 0      23466           ABDULLAH ASLAN                      50
# 1      23582                 ALİ DOST                      50
# 2      23451             AYLİN YILDIZ                      50
# 3      23457            AYSU YILDIRIM                      50
# 4      23570           BAVER AYYILDIZ                      50
# 5      23469               BULUT AZAK                      38
# 6      23596         CEMAL CAN ARSLAN                      42
# 7      23471             DİLAN ERTUNÇ                      50
# 8      23459              ENGİN AYVAT                      50
# 9      23198              ERDAL ŞAHAN                       0
# 10     23458           ERTUĞRUL AYDIN                      46
# 11     23455             FADİME SAÇAR                      50
# 12     23450               FARUK OKAY                      50
# 13     23193          FATİH KARADİKEN                      46
# 14     19031             FURKAN ŞAHİN                      50
# 15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50
# 16     23462            HAKAN ERTİNGÜ                      50
# 17     23139      HÜSEYİN KEVENCİOĞLU                      44
# 18     23472            İBRAHİM YAŞAR                      40
# 19     23456              İSHAK ÖZBEK                      50
# 20     23448        KAAN MAHMUT MACAR                      50
# 21     23196              KÜBRA GÖKÇE                      50
# 22     23467            MERVE NUR KUŞ                      50
# 23     23465             MESUT TEKELİ                      46
# 24     23470       MİRZA MEHMET YÜCEL                      50
# 25     23581      MUHAMMET EMİN KESİK                      50
# 26     23330       MUHAMMET KARADUMAN                      50
# 27     23449   MUHAMMET LÜTFİ BAŞBOĞA                      46
# 28     23138        MUHAMMET YILDIRIM                      50
# 29     23464            MUKADDER KENT                      50
# 30     23452         MUSA OZAN PATACI                      50
# 31     23136              OKTAY AYANA                      46
# 32     23453            ÖMER BOSTANCI                      30
# 33     23195            ÖMER YILDIRIM                      50
# 34     23132              ÖZCAN ÇAKIR                      50
# 35     23463            SERDAR YAZICI                      50
# 36     23460         SERHAT ÇETİNKAYA                      50
# 37     23194               SEYDİ SARI                      50
# 38     23473            ŞAHİN TAŞKAYA                      38
# 39     23580                ŞEYDA ÖRS                      50
# 40     23197                TANER HAN                      50
# 41     23454          TANER HANIMOĞLU                      46
# 42     23461          TARIK YİĞİTBAŞI                      50
# 43     23273              TUĞÇE DOĞAN                      50
# 44     23134              EMRAH KÜÇÜK                       0
# 45     23135           FETHİYE YILMAZ                       0
# 46     23272             ÇETİN ÇELEBİ                       0
# 47     23332        ALİ İHSAN DESTİCİ                       0
# 48     23587                 OKAN GÖK                       0
# 49     23588              TURGAY KAYA                       0
# 50     23340                 ALİ İĞDE                       0
# 51     19781               ALİ DÜNDAR                       0

# %%
filtered_df=df[df['Oturum Süresi (Dakika)']>51*70/100]

# %%
result_list= filtered_df['Oturum Süresi (Dakika)'].tolist()

# %%
result_list
# Out:
# [50,
#  50,
#  50,
#  50,
#  50,
#  38,
#  42,
#  50,
#  50,
#  46,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  44,
#  40,
#  50,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  50,
#  50,
#  38,
#  50,
#  50,
#  46,
#  50,
#  50]

# %%
filtered_df=
# Out:
#   Cell In[26], line 1
#     filtered_df=
#                 ^
# SyntaxError: invalid syntax

# %%
filtered_df=[['Sicil No	', 'Ad Soyad']]

# %%
result_list
# Out:
# [50,
#  50,
#  50,
#  50,
#  50,
#  38,
#  42,
#  50,
#  50,
#  46,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  44,
#  40,
#  50,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  50,
#  50,
#  38,
#  50,
#  50,
#  46,
#  50,
#  50]

# %%
result_list= filtered_df.to_dict('result')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 result_list= filtered_df.to_dict('result')
#
# AttributeError: 'list' object has no attribute 'to_dict'

# %%
result_list= filtered_df.to_dict('Oturum Süresi (Dakika)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 result_list= filtered_df.to_dict('Oturum Süresi (Dakika)')
#
# AttributeError: 'list' object has no attribute 'to_dict'

# %% [raw]
# df

# %%
filtered_df
# Out:
# [['Sicil No\t', 'Ad Soyad']]

# %%
result_list
# Out:
# [50,
#  50,
#  50,
#  50,
#  50,
#  38,
#  42,
#  50,
#  50,
#  46,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  44,
#  40,
#  50,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  46,
#  50,
#  50,
#  50,
#  50,
#  50,
#  38,
#  50,
#  50,
#  46,
#  50,
#  50]

# %%
result_list=[]

# %%
for index,row in filtered_df.iterrows():
# Out:
#   Cell In[38], line 1
#     for index,row in filtered_df.iterrows():
#                                             ^
# SyntaxError: incomplete input

# %%
for index,row in filtered_df.iterrows():
    result_list.append(row.to_dict())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 for index,row in filtered_df.iterrows():
#       2     result_list.append(row.to_dict())
#
# AttributeError: 'list' object has no attribute 'iterrows'

# %%
excel_files=["C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"]
# Out:
#   Cell In[40], line 1
#     excel_files=["C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"]
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
excel_files=['ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx','ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx','ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx','ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx','ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx']

# %%
merged_df= pd.read_excel(excel_files[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 merged_df= pd.read_excel(excel_files[0])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx'

# %%
excel_files
# Out:
# ['ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx',
#  'ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx',
#  'ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx',
#  'ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx',
#  'ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx']

# %%
excel_files=["C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"]
# Out:
#   Cell In[44], line 1
#     excel_files=["C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx","C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"]
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# Excel dosyalarının tam yolları
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# İlk Excel dosyasını oku
merged_df = pd.read_excel(excel_files[0])

# Diğer Excel dosyalarını sırayla birleştir
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df.rename(columns={'Oturum Süresi (Dakika)': f'Oturum Süresi {i}'}, inplace=True)
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])

# Oturum sürelerini toplama
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# Ortalama oturum süresini hesaplama
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# Sonuçları bir Excel dosyasına kaydetme
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
result.to_excel('toplam_ve_ortalama_oturum_sureleri.xlsx', index=False)

print(result)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[46], line 19
#      17     df = pd.read_excel(file)
#      18     df.rename(columns={'Oturum Süresi (Dakika)': f'Oturum Süresi {i}'}, inplace=True)
# ---> 19     merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])
#      21 # Oturum sürelerini toplama
#      22 oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:2757, in _items_overlap_with_suffix(left, right, suffixes)
#    2755     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756 if dups:
# -> 2757     raise MergeError(
#    2758         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759         f"not allowed.",
#    2760     )
#    2762 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'Unnamed: 3_x', 'Unnamed: 4_x'} is not allowed.

# %%
import pandas as pd

# Excel dosyalarının tam yolları
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# İlk Excel dosyasını oku
merged_df = pd.read_excel(excel_files[0])

# Gereksiz sütunları filtreleme (örneğin, isimsiz sütunlar)
merged_df = merged_df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
merged_df.rename(columns={'Oturum Süresi (Dakika)': 'Oturum Süresi 1'}, inplace=True)

# Diğer Excel dosyalarını sırayla birleştir
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df = df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
    df.rename(columns={'Oturum Süresi (Dakika)': f'Oturum Süresi {i}'}, inplace=True)
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])

# Oturum sürelerini toplama
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# Ortalama oturum süresini hesaplama
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# Sonuçları bir Excel dosyasına kaydetme
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
result.to_excel('toplam_ve_ortalama_oturum_sureleri.xlsx', index=False)

print(result)
# Out:
#     Sicil No                 Ad Soyad  Toplam Oturum Süresi  \
# 0      23466           ABDULLAH ASLAN                   208
# 1      23582                 ALİ DOST                   158
# 2      23451             AYLİN YILDIZ                   258
# 3      23457            AYSU YILDIRIM                   204
# 4      23570           BAVER AYYILDIZ                   208
# 5      23469               BULUT AZAK                   212
# 6      23596         CEMAL CAN ARSLAN                   220
# 7      23471             DİLAN ERTUNÇ                   252
# 8      23459              ENGİN AYVAT                   234
# 9      23198              ERDAL ŞAHAN                   154
# 10     23458           ERTUĞRUL AYDIN                   204
# 11     23455             FADİME SAÇAR                   258
# 12     23450               FARUK OKAY                   258
# 13     23193          FATİH KARADİKEN                   218
# 14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                   258
# 15     23462            HAKAN ERTİNGÜ                   259
# 16     23139      HÜSEYİN KEVENCİOĞLU                   244
# 17     23472            İBRAHİM YAŞAR                    40
# 18     23456              İSHAK ÖZBEK                   230
# 19     23448        KAAN MAHMUT MACAR                   258
# 20     23196              KÜBRA GÖKÇE                   206
# 21     23467            MERVE NUR KUŞ                   259
# 22     23465             MESUT TEKELİ                   204
# 23     23470       MİRZA MEHMET YÜCEL                   238
# 24     23581      MUHAMMET EMİN KESİK                   258
# 25     23330       MUHAMMET KARADUMAN                   252
# 26     23449   MUHAMMET LÜTFİ BAŞBOĞA                   242
# 27     23138        MUHAMMET YILDIRIM                   253
# 28     23464            MUKADDER KENT                   206
# 29     23452         MUSA OZAN PATACI                   259
# 30     23136              OKTAY AYANA                   250
# 31     23453            ÖMER BOSTANCI                   226
# 32     23195            ÖMER YILDIRIM                   207
# 33     23132              ÖZCAN ÇAKIR                   248
# 34     23463            SERDAR YAZICI                   258
# 35     23460         SERHAT ÇETİNKAYA                   258
# 36     23194               SEYDİ SARI                   259
# 37     23473            ŞAHİN TAŞKAYA                   228
# 38     23580                ŞEYDA ÖRS                   254
# 39     23197                TANER HAN                   259
# 40     23454          TANER HANIMOĞLU                   254
# 41     23461          TARIK YİĞİTBAŞI                   258
# 42     23273              TUĞÇE DOĞAN                   258
# 43     23134              EMRAH KÜÇÜK                     0
# 44     23135           FETHİYE YILMAZ                     0
# 45     23272             ÇETİN ÇELEBİ                     0
# 46     23332        ALİ İHSAN DESTİCİ                     0
# 47     23587                 OKAN GÖK                    26
# 48     23588              TURGAY KAYA                     0
# 49     23340                 ALİ İĞDE                     0
#
#     Ortalama Oturum Süresi
# 0                     41.6
# 1                     31.6
# 2                     51.6
# 3                     40.8
# 4                     41.6
# 5                     42.4
# 6                     44.0
# 7                     50.4
# 8                     46.8
# 9                     30.8
# 10                    40.8
# 11                    51.6
# 12                    51.6
# 13                    43.6
# 14                    51.6
# 15                    51.8
# 16                    48.8
# 17                     8.0
# 18                    46.0
# 19                    51.6
# 20                    41.2
# 21                    51.8
# 22                    40.8
# 23                    47.6
# 24                    51.6
# 25                    50.4
# 26                    48.4
# 27                    50.6
# 28                    41.2
# 29                    51.8
# 30                    50.0
# 31                    45.2
# 32                    41.4
# 33                    49.6
# 34                    51.6
# 35                    51.6
# 36                    51.8
# 37                    45.6
# 38                    50.8
# 39                    51.8
# 40                    50.8
# 41                    51.6
# 42                    51.6
# 43                     0.0
# 44                     0.0
# 45                     0.0
# 46                     0.0
# 47                     5.2
# 48                     0.0
# 49                     0.0

# %%
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# %%
merged_df = pd.read_excel(excel_files[0])

# %%
merged_df = merged_df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
merged_df.rename(columns={'Oturum Süresi (Dakika)': 'Oturum Süresi 1'}, inplace=True)

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df = df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
    df.rename(columns={'Oturum Süresi (Dakika)': f'Oturum Süresi {i}'}, inplace=True)
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])

# %%
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# %%
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# %%
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
result.to_excel('toplam_ve_ortalama_oturum_sureleri.xlsx', index=False)

# %%
result
# Out:
#     Sicil No                 Ad Soyad  Toplam Oturum Süresi  \
# 0      23466           ABDULLAH ASLAN                   208
# 1      23582                 ALİ DOST                   158
# 2      23451             AYLİN YILDIZ                   258
# 3      23457            AYSU YILDIRIM                   204
# 4      23570           BAVER AYYILDIZ                   208
# 5      23469               BULUT AZAK                   212
# 6      23596         CEMAL CAN ARSLAN                   220
# 7      23471             DİLAN ERTUNÇ                   252
# 8      23459              ENGİN AYVAT                   234
# 9      23198              ERDAL ŞAHAN                   154
# 10     23458           ERTUĞRUL AYDIN                   204
# 11     23455             FADİME SAÇAR                   258
# 12     23450               FARUK OKAY                   258
# 13     23193          FATİH KARADİKEN                   218
# 14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                   258
# 15     23462            HAKAN ERTİNGÜ                   259
# 16     23139      HÜSEYİN KEVENCİOĞLU                   244
# 17     23472            İBRAHİM YAŞAR                    40
# 18     23456              İSHAK ÖZBEK                   230
# 19     23448        KAAN MAHMUT MACAR                   258
# 20     23196              KÜBRA GÖKÇE                   206
# 21     23467            MERVE NUR KUŞ                   259
# 22     23465             MESUT TEKELİ                   204
# 23     23470       MİRZA MEHMET YÜCEL                   238
# 24     23581      MUHAMMET EMİN KESİK                   258
# 25     23330       MUHAMMET KARADUMAN                   252
# 26     23449   MUHAMMET LÜTFİ BAŞBOĞA                   242
# 27     23138        MUHAMMET YILDIRIM                   253
# 28     23464            MUKADDER KENT                   206
# 29     23452         MUSA OZAN PATACI                   259
# 30     23136              OKTAY AYANA                   250
# 31     23453            ÖMER BOSTANCI                   226
# 32     23195            ÖMER YILDIRIM                   207
# 33     23132              ÖZCAN ÇAKIR                   248
# 34     23463            SERDAR YAZICI                   258
# 35     23460         SERHAT ÇETİNKAYA                   258
# 36     23194               SEYDİ SARI                   259
# 37     23473            ŞAHİN TAŞKAYA                   228
# 38     23580                ŞEYDA ÖRS                   254
# 39     23197                TANER HAN                   259
# 40     23454          TANER HANIMOĞLU                   254
# 41     23461          TARIK YİĞİTBAŞI                   258
# 42     23273              TUĞÇE DOĞAN                   258
# 43     23134              EMRAH KÜÇÜK                     0
# 44     23135           FETHİYE YILMAZ                     0
# 45     23272             ÇETİN ÇELEBİ                     0
# 46     23332        ALİ İHSAN DESTİCİ                     0
# 47     23587                 OKAN GÖK                    26
# 48     23588              TURGAY KAYA                     0
# 49     23340                 ALİ İĞDE                     0
#
#     Ortalama Oturum Süresi
# 0                     41.6
# 1                     31.6
# 2                     51.6
# 3                     40.8
# 4                     41.6
# 5                     42.4
# 6                     44.0
# 7                     50.4
# 8                     46.8
# 9                     30.8
# 10                    40.8
# 11                    51.6
# 12                    51.6
# 13                    43.6
# 14                    51.6
# 15                    51.8
# 16                    48.8
# 17                     8.0
# 18                    46.0
# 19                    51.6
# 20                    41.2
# 21                    51.8
# 22                    40.8
# 23                    47.6
# 24                    51.6
# 25                    50.4
# 26                    48.4
# 27                    50.6
# 28                    41.2
# 29                    51.8
# 30                    50.0
# 31                    45.2
# 32                    41.4
# 33                    49.6
# 34                    51.6
# 35                    51.6
# 36                    51.8
# 37                    45.6
# 38                    50.8
# 39                    51.8
# 40                    50.8
# 41                    51.6
# 42                    51.6
# 43                     0.0
# 44                     0.0
# 45                     0.0
# 46                     0.0
# 47                     5.2
# 48                     0.0
# 49                     0.0

# %%
merged_df=merged_df,iloc[:,[0,1,3]]
merged_df.columns=['Sicil No','Ad Soyad','Ders Saati']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 merged_df=merged_df,iloc[:,[0,1,3]]
#       2 merged_df.columns=['Sicil No','Ad Soyad','Ders Saati']
#
# NameError: name 'iloc' is not defined

# %%
merged_df=merged_df.iloc[:,[0,1,3]]
merged_df.columns=['Sicil No','Ad Soyad','Ders Saati']

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df = df.iloc[:,[0,1,3]]
    df.columns=['Sicil No','Ad Soyad','Ders Saati']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[58], line 5
#       3 df = df.iloc[:,[0,1,3]]
#       4 df.columns=['Sicil No','Ad Soyad','Ders Saati']
# ----> 5 merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:2757, in _items_overlap_with_suffix(left, right, suffixes)
#    2755     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756 if dups:
# -> 2757     raise MergeError(
#    2758         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759         f"not allowed.",
#    2760     )
#    2762 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'Ders Saati_x'} is not allowed.

# %%
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# %%
merged_df = pd.read_excel(excel_files[0])

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df = df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
    df.rename(columns={'Oturum Süresi (Dakika)': f'Oturum Süresi {i}'}, inplace=True)
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])

# %%
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# %%
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# %%
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]

# %%
result.to_excel('toplam_ve_ortalama_oturum_sureleri.xlsx', index=False)

# %%
result
# Out:
#     Sicil No                 Ad Soyad  Toplam Oturum Süresi  \
# 0      23466           ABDULLAH ASLAN                   208
# 1      23582                 ALİ DOST                   158
# 2      23451             AYLİN YILDIZ                   258
# 3      23457            AYSU YILDIRIM                   204
# 4      23570           BAVER AYYILDIZ                   208
# 5      23469               BULUT AZAK                   212
# 6      23596         CEMAL CAN ARSLAN                   220
# 7      23471             DİLAN ERTUNÇ                   252
# 8      23459              ENGİN AYVAT                   234
# 9      23198              ERDAL ŞAHAN                   154
# 10     23458           ERTUĞRUL AYDIN                   204
# 11     23455             FADİME SAÇAR                   258
# 12     23450               FARUK OKAY                   258
# 13     23193          FATİH KARADİKEN                   218
# 14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                   258
# 15     23462            HAKAN ERTİNGÜ                   259
# 16     23139      HÜSEYİN KEVENCİOĞLU                   244
# 17     23472            İBRAHİM YAŞAR                    40
# 18     23456              İSHAK ÖZBEK                   230
# 19     23448        KAAN MAHMUT MACAR                   258
# 20     23196              KÜBRA GÖKÇE                   206
# 21     23467            MERVE NUR KUŞ                   259
# 22     23465             MESUT TEKELİ                   204
# 23     23470       MİRZA MEHMET YÜCEL                   238
# 24     23581      MUHAMMET EMİN KESİK                   258
# 25     23330       MUHAMMET KARADUMAN                   252
# 26     23449   MUHAMMET LÜTFİ BAŞBOĞA                   242
# 27     23138        MUHAMMET YILDIRIM                   253
# 28     23464            MUKADDER KENT                   206
# 29     23452         MUSA OZAN PATACI                   259
# 30     23136              OKTAY AYANA                   250
# 31     23453            ÖMER BOSTANCI                   226
# 32     23195            ÖMER YILDIRIM                   207
# 33     23132              ÖZCAN ÇAKIR                   248
# 34     23463            SERDAR YAZICI                   258
# 35     23460         SERHAT ÇETİNKAYA                   258
# 36     23194               SEYDİ SARI                   259
# 37     23473            ŞAHİN TAŞKAYA                   228
# 38     23580                ŞEYDA ÖRS                   254
# 39     23197                TANER HAN                   259
# 40     23454          TANER HANIMOĞLU                   254
# 41     23461          TARIK YİĞİTBAŞI                   258
# 42     23273              TUĞÇE DOĞAN                   258
# 43     23134              EMRAH KÜÇÜK                     0
# 44     23135           FETHİYE YILMAZ                     0
# 45     23272             ÇETİN ÇELEBİ                     0
# 46     23332        ALİ İHSAN DESTİCİ                     0
# 47     23587                 OKAN GÖK                    26
# 48     23588              TURGAY KAYA                     0
# 49     23340                 ALİ İĞDE                     0
#
#     Ortalama Oturum Süresi
# 0                     41.6
# 1                     31.6
# 2                     51.6
# 3                     40.8
# 4                     41.6
# 5                     42.4
# 6                     44.0
# 7                     50.4
# 8                     46.8
# 9                     30.8
# 10                    40.8
# 11                    51.6
# 12                    51.6
# 13                    43.6
# 14                    51.6
# 15                    51.8
# 16                    48.8
# 17                     8.0
# 18                    46.0
# 19                    51.6
# 20                    41.2
# 21                    51.8
# 22                    40.8
# 23                    47.6
# 24                    51.6
# 25                    50.4
# 26                    48.4
# 27                    50.6
# 28                    41.2
# 29                    51.8
# 30                    50.0
# 31                    45.2
# 32                    41.4
# 33                    49.6
# 34                    51.6
# 35                    51.6
# 36                    51.8
# 37                    45.6
# 38                    50.8
# 39                    51.8
# 40                    50.8
# 41                    51.6
# 42                    51.6
# 43                     0.0
# 44                     0.0
# 45                     0.0
# 46                     0.0
# 47                     5.2
# 48                     0.0
# 49                     0.0

# %%
result
# Out:
#     Sicil No                 Ad Soyad  Toplam Ders Saati  Ortalama Ders Saati
# 0      23466           ABDULLAH ASLAN                0.0                  0.0
# 1      23582                 ALİ DOST                0.0                  0.0
# 2      23451             AYLİN YILDIZ                0.0                  0.0
# 3      23457            AYSU YILDIRIM                0.0                  0.0
# 4      23570           BAVER AYYILDIZ                0.0                  0.0
# 5      23469               BULUT AZAK                0.0                  0.0
# 6      23596         CEMAL CAN ARSLAN                0.0                  0.0
# 7      23471             DİLAN ERTUNÇ                0.0                  0.0
# 8      23459              ENGİN AYVAT                0.0                  0.0
# 9      23198              ERDAL ŞAHAN                0.0                  0.0
# 10     23458           ERTUĞRUL AYDIN                0.0                  0.0
# 11     23455             FADİME SAÇAR                0.0                  0.0
# 12     23450               FARUK OKAY                0.0                  0.0
# 13     23193          FATİH KARADİKEN                0.0                  0.0
# 14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                0.0                  0.0
# 15     23462            HAKAN ERTİNGÜ                0.0                  0.0
# 16     23139      HÜSEYİN KEVENCİOĞLU                0.0                  0.0
# 17     23472            İBRAHİM YAŞAR                0.0                  0.0
# 18     23456              İSHAK ÖZBEK                0.0                  0.0
# 19     23448        KAAN MAHMUT MACAR                0.0                  0.0
# 20     23196              KÜBRA GÖKÇE                0.0                  0.0
# 21     23467            MERVE NUR KUŞ                0.0                  0.0
# 22     23465             MESUT TEKELİ                0.0                  0.0
# 23     23470       MİRZA MEHMET YÜCEL                0.0                  0.0
# 24     23581      MUHAMMET EMİN KESİK                0.0                  0.0
# 25     23330       MUHAMMET KARADUMAN                0.0                  0.0
# 26     23449   MUHAMMET LÜTFİ BAŞBOĞA                0.0                  0.0
# 27     23138        MUHAMMET YILDIRIM                0.0                  0.0
# 28     23464            MUKADDER KENT                0.0                  0.0
# 29     23452         MUSA OZAN PATACI                0.0                  0.0
# 30     23136              OKTAY AYANA                0.0                  0.0
# 31     23453            ÖMER BOSTANCI                0.0                  0.0
# 32     23195            ÖMER YILDIRIM                0.0                  0.0
# 33     23132              ÖZCAN ÇAKIR                0.0                  0.0
# 34     23463            SERDAR YAZICI                0.0                  0.0
# 35     23460         SERHAT ÇETİNKAYA                0.0                  0.0
# 36     23194               SEYDİ SARI                0.0                  0.0
# 37     23473            ŞAHİN TAŞKAYA                0.0                  0.0
# 38     23580                ŞEYDA ÖRS                0.0                  0.0
# 39     23197                TANER HAN                0.0                  0.0
# 40     23454          TANER HANIMOĞLU                0.0                  0.0
# 41     23461          TARIK YİĞİTBAŞI                0.0                  0.0
# 42     23273              TUĞÇE DOĞAN                0.0                  0.0
# 43     23134              EMRAH KÜÇÜK                0.0                  0.0
# 44     23135           FETHİYE YILMAZ                0.0                  0.0
# 45     23272             ÇETİN ÇELEBİ                0.0                  0.0
# 46     23332        ALİ İHSAN DESTİCİ                0.0                  0.0
# 47     23587                 OKAN GÖK                0.0                  0.0
# 48     23588              TURGAY KAYA                0.0                  0.0
# 49     23340                 ALİ İĞDE                0.0                  0.0

# %%
import pandas as pd

# Excel dosyalarının tam yolları
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# İlk Excel dosyasını oku
merged_df = pd.read_excel(excel_files[0])

# Genel ders süresini alma ve toplam genel ders süresini hesaplama
genel_ders_suresi = merged_df.iloc[0, 4]  # 5. sütun genel ders süresi
merged_df = merged_df.iloc[1:, [0, 1, 2]]
merged_df.columns = ['Sicil No', 'Ad Soyad', 'Oturum Süresi 1']

# Diğer Excel dosyalarını sırayla birleştir
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    genel_ders_suresi += df.iloc[0, 4]  # 5. sütun genel ders süresi
    df = df.iloc[1:, [0, 1, 2]]
    df.columns = ['Sicil No', 'Ad Soyad', f'Oturum Süresi {i}']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'], how='inner')

# Oturum sürelerini toplama
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# Ortalama oturum süresini hesaplama
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# Genel ders süresinin yüzde 70'ine veya daha fazlasına katılanları filtreleme
katilim_limiti = genel_ders_suresi * 0.70
katilanlar = merged_df[merged_df['Toplam Oturum Süresi'] >= katilim_limiti]

# Sonuçları bir Excel dosyasına kaydetme
sonuc = katilanlar[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
sonuc['Genel Ders Süresi'] = genel_ders_suresi  # Genel ders süresini ekle

sonuc.to_excel('katilimci_ogrenciler.xlsx', index=False)

print(sonuc)
# Out:
# Empty DataFrame
# Columns: [Sicil No, Ad Soyad, Toplam Oturum Süresi, Ortalama Oturum Süresi, Genel Ders Süresi]
# Index: []

# %%
import pandas as pd

# Excel dosyalarının tam yolları
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# İlk Excel dosyasını oku
merged_df = pd.read_excel(excel_files[0])

# Genel ders süresini alma ve toplam genel ders süresini hesaplama
genel_ders_sureleri = [merged_df.iloc[0, 4]]
merged_df = merged_df.iloc[1:, [0, 1, 2]]
merged_df.columns = ['Sicil No', 'Ad Soyad', 'Oturum Süresi 1']

# Diğer Excel dosyalarını sırayla birleştir
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    genel_ders_sureleri.append(df.iloc[0, 4])  # 5. sütun genel ders süresi
    df = df.iloc[1:, [0, 1, 2]]
    df.columns = ['Sicil No', 'Ad Soyad', f'Oturum Süresi {i}']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'], how='outer')

# Boş olan oturum sürelerini 0 ile doldur
merged_df.fillna(0, inplace=True)

# Oturum sürelerini toplama
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# Ortalama oturum süresini hesaplama
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# Genel ders süresinin toplamı
genel_ders_suresi = sum(genel_ders_sureleri)

# Genel ders süresinin yüzde 70'ine veya daha fazlasına katılanları filtreleme
katilim_limiti = genel_ders_suresi * 0.70
katilanlar = merged_df[merged_df['Toplam Oturum Süresi'] >= katilim_limiti]

# Sonuçları bir Excel dosyasına kaydetme
sonuc = katilanlar[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
sonuc['Genel Ders Süresi'] = genel_ders_suresi  # Genel ders süresini ekle

sonuc.to_excel('katilimci_ogrenciler.xlsx', index=False)

print(sonuc)
# Out:
# Empty DataFrame
# Columns: [Sicil No, Ad Soyad, Toplam Oturum Süresi, Ortalama Oturum Süresi, Genel Ders Süresi]
# Index: []

# %%
import pandas as pd

# Excel dosyalarının tam yolları
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# İlk Excel dosyasını oku
merged_df = pd.read_excel(excel_files[0])

# Genel ders süresini alma ve toplam genel ders süresini hesaplama
genel_ders_sureleri = [merged_df.iloc[0, 4]]
merged_df = merged_df.iloc[1:, [0, 1, 2]]
merged_df.columns = ['Sicil No', 'Ad Soyad', 'Oturum Süresi 1']

# Diğer Excel dosyalarını sırayla birleştir
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    genel_ders_sureleri.append(df.iloc[0, 4])  # 5. sütun genel ders süresi
    df = df.iloc[1:, [0, 1, 2]]
    df.columns = ['Sicil No', 'Ad Soyad', f'Oturum Süresi {i}']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'], how='outer')

# Boş olan oturum sürelerini 0 ile doldur
merged_df.fillna(0, inplace=True)

# Oturum sürelerini toplama
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# Ortalama oturum süresini hesaplama
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# Genel ders süresinin toplamı
genel_ders_suresi = sum(genel_ders_sureleri)

# Genel ders süresinin yüzde 70'ine veya daha fazlasına katılanları filtreleme
katilim_limiti = genel_ders_suresi * 0.70
katilanlar = merged_df[merged_df['Toplam Oturum Süresi'] >= katilim_limiti]

# Sonuçları bir Excel dosyasına kaydetme
sonuc = katilanlar[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
sonuc['Genel Ders Süresi'] = genel_ders_suresi  # Genel ders süresini ekle

sonuc.to_excel('katilimci_ogrenciler.xlsx', index=False)

print(sonuc)
# Out:
# Empty DataFrame
# Columns: [Sicil No, Ad Soyad, Toplam Oturum Süresi, Ortalama Oturum Süresi, Genel Ders Süresi]
# Index: []

# %%
excel_files = [
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx",
    r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
]

# %%
merged_df = pd.read_excel(excel_files[0])
merged_df = merged_df.iloc[:, [0, 1, 3]]  # Sadece 'Sicil No', 'Ad Soyad' ve 4. sütun (Ders Saati) alınır
merged_df.columns = ['Sicil No', 'Ad Soyad', 'Ders Saati 1']

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df = df.iloc[:, [0, 1, 3]]  # Sadece 'Sicil No', 'Ad Soyad' ve 4. sütun (Ders Saati) alınır
    df.columns = ['Sicil No', 'Ad Soyad', f'Ders Saati {i}']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'], how='inner')

# %%
ders_saatleri_sutunlari = [col for col in merged_df.columns if 'Ders Saati' in col]
merged_df['Toplam Ders Saati'] = merged_df[ders_saatleri_sutunlari].sum(axis=1)

# %%
merged_df['Ortalama Ders Saati'] = merged_df['Toplam Ders Saati'] / len(excel_files)

# %%
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Ders Saati', 'Ortalama Ders Saati']]
result.to_excel('toplam_ve_ortalama_ders_saatleri.xlsx', index=False)

# %%
result
# Out:
#     Sicil No                 Ad Soyad  Toplam Ders Saati  Ortalama Ders Saati
# 0      23466           ABDULLAH ASLAN                0.0                  0.0
# 1      23582                 ALİ DOST                0.0                  0.0
# 2      23451             AYLİN YILDIZ                0.0                  0.0
# 3      23457            AYSU YILDIRIM                0.0                  0.0
# 4      23570           BAVER AYYILDIZ                0.0                  0.0
# 5      23469               BULUT AZAK                0.0                  0.0
# 6      23596         CEMAL CAN ARSLAN                0.0                  0.0
# 7      23471             DİLAN ERTUNÇ                0.0                  0.0
# 8      23459              ENGİN AYVAT                0.0                  0.0
# 9      23198              ERDAL ŞAHAN                0.0                  0.0
# 10     23458           ERTUĞRUL AYDIN                0.0                  0.0
# 11     23455             FADİME SAÇAR                0.0                  0.0
# 12     23450               FARUK OKAY                0.0                  0.0
# 13     23193          FATİH KARADİKEN                0.0                  0.0
# 14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                0.0                  0.0
# 15     23462            HAKAN ERTİNGÜ                0.0                  0.0
# 16     23139      HÜSEYİN KEVENCİOĞLU                0.0                  0.0
# 17     23472            İBRAHİM YAŞAR                0.0                  0.0
# 18     23456              İSHAK ÖZBEK                0.0                  0.0
# 19     23448        KAAN MAHMUT MACAR                0.0                  0.0
# 20     23196              KÜBRA GÖKÇE                0.0                  0.0
# 21     23467            MERVE NUR KUŞ                0.0                  0.0
# 22     23465             MESUT TEKELİ                0.0                  0.0
# 23     23470       MİRZA MEHMET YÜCEL                0.0                  0.0
# 24     23581      MUHAMMET EMİN KESİK                0.0                  0.0
# 25     23330       MUHAMMET KARADUMAN                0.0                  0.0
# 26     23449   MUHAMMET LÜTFİ BAŞBOĞA                0.0                  0.0
# 27     23138        MUHAMMET YILDIRIM                0.0                  0.0
# 28     23464            MUKADDER KENT                0.0                  0.0
# 29     23452         MUSA OZAN PATACI                0.0                  0.0
# 30     23136              OKTAY AYANA                0.0                  0.0
# 31     23453            ÖMER BOSTANCI                0.0                  0.0
# 32     23195            ÖMER YILDIRIM                0.0                  0.0
# 33     23132              ÖZCAN ÇAKIR                0.0                  0.0
# 34     23463            SERDAR YAZICI                0.0                  0.0
# 35     23460         SERHAT ÇETİNKAYA                0.0                  0.0
# 36     23194               SEYDİ SARI                0.0                  0.0
# 37     23473            ŞAHİN TAŞKAYA                0.0                  0.0
# 38     23580                ŞEYDA ÖRS                0.0                  0.0
# 39     23197                TANER HAN                0.0                  0.0
# 40     23454          TANER HANIMOĞLU                0.0                  0.0
# 41     23461          TARIK YİĞİTBAŞI                0.0                  0.0
# 42     23273              TUĞÇE DOĞAN                0.0                  0.0
# 43     23134              EMRAH KÜÇÜK                0.0                  0.0
# 44     23135           FETHİYE YILMAZ                0.0                  0.0
# 45     23272             ÇETİN ÇELEBİ                0.0                  0.0
# 46     23332        ALİ İHSAN DESTİCİ                0.0                  0.0
# 47     23587                 OKAN GÖK                0.0                  0.0
# 48     23588              TURGAY KAYA                0.0                  0.0
# 49     23340                 ALİ İĞDE                0.0                  0.0

# %%
merged_df = pd.read_excel(excel_files[0])
genel_ders_suresi = merged_df.iloc[0, 3]
merged_df = merged_df.iloc[1:, [0, 1, 3]]  # Sadece 'Sicil No', 'Ad Soyad' ve 4. sütun (Oturum Süresi) alınır
merged_df.columns = ['Sicil No', 'Ad Soyad', 'Oturum Süresi 1']

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    genel_ders_suresi += df.iloc[0, 3]
    df = df.iloc[1:, [0, 1, 3]]  # Sadece 'Sicil No', 'Ad Soyad' ve 4. sütun (Oturum Süresi) alınır
    df.columns = ['Sicil No', 'Ad Soyad', f'Oturum Süresi {i}']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'], how='inner')

# %%
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# %%
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# %%
merged_df['Genel Ders Süresi'] = genel_ders_suresi

# %%
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi', 'Genel Ders Süresi']]
result.to_excel('toplam_ve_ortalama_oturum_sureleri.xlsx', index=False)

# %%
result
# Out:
#     Sicil No                 Ad Soyad  Toplam Oturum Süresi  \
# 0      23582                 ALİ DOST                   0.0
# 1      23451             AYLİN YILDIZ                   0.0
# 2      23457            AYSU YILDIRIM                   0.0
# 3      23570           BAVER AYYILDIZ                   0.0
# 4      23469               BULUT AZAK                   0.0
# 5      23596         CEMAL CAN ARSLAN                   0.0
# 6      23471             DİLAN ERTUNÇ                   0.0
# 7      23459              ENGİN AYVAT                   0.0
# 8      23198              ERDAL ŞAHAN                   0.0
# 9      23458           ERTUĞRUL AYDIN                   0.0
# 10     23455             FADİME SAÇAR                   0.0
# 11     23450               FARUK OKAY                   0.0
# 12     23193          FATİH KARADİKEN                   0.0
# 13     23468  GÜRHAN MUSTAFA ÇINARBAŞ                   0.0
# 14     23462            HAKAN ERTİNGÜ                   0.0
# 15     23139      HÜSEYİN KEVENCİOĞLU                   0.0
# 16     23472            İBRAHİM YAŞAR                   0.0
# 17     23456              İSHAK ÖZBEK                   0.0
# 18     23448        KAAN MAHMUT MACAR                   0.0
# 19     23196              KÜBRA GÖKÇE                   0.0
# 20     23467            MERVE NUR KUŞ                   0.0
# 21     23465             MESUT TEKELİ                   0.0
# 22     23470       MİRZA MEHMET YÜCEL                   0.0
# 23     23581      MUHAMMET EMİN KESİK                   0.0
# 24     23330       MUHAMMET KARADUMAN                   0.0
# 25     23449   MUHAMMET LÜTFİ BAŞBOĞA                   0.0
# 26     23138        MUHAMMET YILDIRIM                   0.0
# 27     23464            MUKADDER KENT                   0.0
# 28     23452         MUSA OZAN PATACI                   0.0
# 29     23136              OKTAY AYANA                   0.0
# 30     23453            ÖMER BOSTANCI                   0.0
# 31     23195            ÖMER YILDIRIM                   0.0
# 32     23132              ÖZCAN ÇAKIR                   0.0
# 33     23463            SERDAR YAZICI                   0.0
# 34     23460         SERHAT ÇETİNKAYA                   0.0
# 35     23194               SEYDİ SARI                   0.0
# 36     23473            ŞAHİN TAŞKAYA                   0.0
# 37     23580                ŞEYDA ÖRS                   0.0
# 38     23197                TANER HAN                   0.0
# 39     23454          TANER HANIMOĞLU                   0.0
# 40     23461          TARIK YİĞİTBAŞI                   0.0
# 41     23273              TUĞÇE DOĞAN                   0.0
# 42     23134              EMRAH KÜÇÜK                   0.0
# 43     23135           FETHİYE YILMAZ                   0.0
# 44     23272             ÇETİN ÇELEBİ                   0.0
# 45     23332        ALİ İHSAN DESTİCİ                   0.0
# 46     23587                 OKAN GÖK                   0.0
# 47     23588              TURGAY KAYA                   0.0
# 48     23340                 ALİ İĞDE                   0.0
#
#     Ortalama Oturum Süresi  Genel Ders Süresi
# 0                      0.0                NaN
# 1                      0.0                NaN
# 2                      0.0                NaN
# 3                      0.0                NaN
# 4                      0.0                NaN
# 5                      0.0                NaN
# 6                      0.0                NaN
# 7                      0.0                NaN
# 8                      0.0                NaN
# 9                      0.0                NaN
# 10                     0.0                NaN
# 11                     0.0                NaN
# 12                     0.0                NaN
# 13                     0.0                NaN
# 14                     0.0                NaN
# 15                     0.0                NaN
# 16                     0.0                NaN
# 17                     0.0                NaN
# 18                     0.0                NaN
# 19                     0.0                NaN
# 20                     0.0                NaN
# 21                     0.0                NaN
# 22                     0.0                NaN
# 23                     0.0                NaN
# 24                     0.0                NaN
# 25                     0.0                NaN
# 26                     0.0                NaN
# 27                     0.0                NaN
# 28                     0.0                NaN
# 29                     0.0                NaN
# 30                     0.0                NaN
# 31                     0.0                NaN
# 32                     0.0                NaN
# 33                     0.0                NaN
# 34                     0.0                NaN
# 35                     0.0                NaN
# 36                     0.0                NaN
# 37                     0.0                NaN
# 38                     0.0                NaN
# 39                     0.0                NaN
# 40                     0.0                NaN
# 41                     0.0                NaN
# 42                     0.0                NaN
# 43                     0.0                NaN
# 44                     0.0                NaN
# 45                     0.0                NaN
# 46                     0.0                NaN
# 47                     0.0                NaN
# 48                     0.0                NaN

# %%
genel_ders_suresi = merged_df.iloc[0, 3]
merged_df = merged_df.iloc[1:, [0, 1, 3]]
merged_df.columns = ['Sicil No', 'Ad Soyad', 'Oturum Süresi 1']

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    genel_ders_suresi += df.iloc[0, 3]
    df = df.iloc[1:, [0, 1, 3]]
    df.columns = ['Sicil No', 'Ad Soyad', f'Oturum Süresi {i}']
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'], how='inner')

# %%
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# %%
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# %%
katilim_limiti = genel_ders_suresi * 0.70
katilanlar = merged_df[merged_df['Toplam Oturum Süresi'] >= katilim_limiti]

# %%
sonuc = katilanlar[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi', 'Genel Ders Süresi']]
sonuc['Genel Ders Süresi'] = genel_ders_suresi
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 sonuc = katilanlar[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi', 'Genel Ders Süresi']]
#       2 sonuc['Genel Ders Süresi'] = genel_ders_suresi
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Genel Ders Süresi'] not in index"

# %%
merged_df = pd.read_excel(excel_files[0])

# %%
merged_df = merged_df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
merged_df.rename(columns={'Oturum Süresi (Dakika)': 'Oturum Süresi 1'}, inplace=True)

# %%
for i, file in enumerate(excel_files[1:], start=2):
    df = pd.read_excel(file)
    df = df[['Sicil No', 'Ad Soyad', 'Oturum Süresi (Dakika)']]
    df.rename(columns={'Oturum Süresi (Dakika)': f'Oturum Süresi {i}'}, inplace=True)
    merged_df = merged_df.merge(df, on=['Sicil No', 'Ad Soyad'])

# %%
oturum_sureleri_sutunlari = [col for col in merged_df.columns if 'Oturum Süresi' in col]
merged_df['Toplam Oturum Süresi'] = merged_df[oturum_sureleri_sutunlari].sum(axis=1)

# %%
merged_df['Ortalama Oturum Süresi'] = merged_df['Toplam Oturum Süresi'] / len(excel_files)

# %%
result = merged_df[['Sicil No', 'Ad Soyad', 'Toplam Oturum Süresi', 'Ortalama Oturum Süresi']]
result.to_excel('toplam_ve_ortalama_oturum_sureleri.xlsx', index=False)

# %%
result
# Out:
#     Sicil No                 Ad Soyad  Toplam Oturum Süresi  \
# 0      23466           ABDULLAH ASLAN                   208
# 1      23582                 ALİ DOST                   158
# 2      23451             AYLİN YILDIZ                   258
# 3      23457            AYSU YILDIRIM                   204
# 4      23570           BAVER AYYILDIZ                   208
# 5      23469               BULUT AZAK                   212
# 6      23596         CEMAL CAN ARSLAN                   220
# 7      23471             DİLAN ERTUNÇ                   252
# 8      23459              ENGİN AYVAT                   234
# 9      23198              ERDAL ŞAHAN                   154
# 10     23458           ERTUĞRUL AYDIN                   204
# 11     23455             FADİME SAÇAR                   258
# 12     23450               FARUK OKAY                   258
# 13     23193          FATİH KARADİKEN                   218
# 14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                   258
# 15     23462            HAKAN ERTİNGÜ                   259
# 16     23139      HÜSEYİN KEVENCİOĞLU                   244
# 17     23472            İBRAHİM YAŞAR                    40
# 18     23456              İSHAK ÖZBEK                   230
# 19     23448        KAAN MAHMUT MACAR                   258
# 20     23196              KÜBRA GÖKÇE                   206
# 21     23467            MERVE NUR KUŞ                   259
# 22     23465             MESUT TEKELİ                   204
# 23     23470       MİRZA MEHMET YÜCEL                   238
# 24     23581      MUHAMMET EMİN KESİK                   258
# 25     23330       MUHAMMET KARADUMAN                   252
# 26     23449   MUHAMMET LÜTFİ BAŞBOĞA                   242
# 27     23138        MUHAMMET YILDIRIM                   253
# 28     23464            MUKADDER KENT                   206
# 29     23452         MUSA OZAN PATACI                   259
# 30     23136              OKTAY AYANA                   250
# 31     23453            ÖMER BOSTANCI                   226
# 32     23195            ÖMER YILDIRIM                   207
# 33     23132              ÖZCAN ÇAKIR                   248
# 34     23463            SERDAR YAZICI                   258
# 35     23460         SERHAT ÇETİNKAYA                   258
# 36     23194               SEYDİ SARI                   259
# 37     23473            ŞAHİN TAŞKAYA                   228
# 38     23580                ŞEYDA ÖRS                   254
# 39     23197                TANER HAN                   259
# 40     23454          TANER HANIMOĞLU                   254
# 41     23461          TARIK YİĞİTBAŞI                   258
# 42     23273              TUĞÇE DOĞAN                   258
# 43     23134              EMRAH KÜÇÜK                     0
# 44     23135           FETHİYE YILMAZ                     0
# 45     23272             ÇETİN ÇELEBİ                     0
# 46     23332        ALİ İHSAN DESTİCİ                     0
# 47     23587                 OKAN GÖK                    26
# 48     23588              TURGAY KAYA                     0
# 49     23340                 ALİ İĞDE                     0
#
#     Ortalama Oturum Süresi
# 0                     41.6
# 1                     31.6
# 2                     51.6
# 3                     40.8
# 4                     41.6
# 5                     42.4
# 6                     44.0
# 7                     50.4
# 8                     46.8
# 9                     30.8
# 10                    40.8
# 11                    51.6
# 12                    51.6
# 13                    43.6
# 14                    51.6
# 15                    51.8
# 16                    48.8
# 17                     8.0
# 18                    46.0
# 19                    51.6
# 20                    41.2
# 21                    51.8
# 22                    40.8
# 23                    47.6
# 24                    51.6
# 25                    50.4
# 26                    48.4
# 27                    50.6
# 28                    41.2
# 29                    51.8
# 30                    50.0
# 31                    45.2
# 32                    41.4
# 33                    49.6
# 34                    51.6
# 35                    51.6
# 36                    51.8
# 37                    45.6
# 38                    50.8
# 39                    51.8
# 40                    50.8
# 41                    51.6
# 42                    51.6
# 43                     0.0
# 44                     0.0
# 45                     0.0
# 46                     0.0
# 47                     5.2
# 48                     0.0
# 49                     0.0

# %%
import glob

# %%
df.iloc[4]
# Out:
# Sicil No                      23596
# Ad Soyad           CEMAL CAN ARSLAN
# Oturum Süresi 5                  44
# Name: 4, dtype: object

# %%
df.iloc[[2],[4]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 df.iloc[[2],[4]]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     964 for i, k in enumerate(key):
#     965     try:
# --> 966         self._validate_key(k, i)
#     967     except ValueError as err:
#     968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1612, in _iLocIndexer._validate_key(self, key, axis)
#    1610     # check that the key does not exceed the maximum size of the index
#    1611     if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
# -> 1612         raise IndexError("positional indexers are out-of-bounds")
#    1613 else:
#    1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# IndexError: positional indexers are out-of-bounds

# %%
df.iloc[2,4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df.iloc[2,4]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4211, in DataFrame._get_value(self, index, col, takeable)
#    4192 """
#    4193 Quickly retrieve single value at passed column and index.
#    4194
#    (...)
#    4208 `self.columns._index_as_unique`; Caller is responsible for checking.
#    4209 """
#    4210 if takeable:
# -> 4211     series = self._ixs(col, axis=1)
#    4212     return series._values[index]
#    4214 series = self._get_item_cache(col)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4008, in DataFrame._ixs(self, i, axis)
#    4004     return result
#    4006 # icol
#    4007 else:
# -> 4008     label = self.columns[i]
#    4010     col_mgr = self._mgr.iget(i)
#    4011     result = self._box_col_values(col_mgr, i)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
#    5387     # GH#44051 exclude bool, which would return a 2d ndarray
#    5388     key = com.cast_scalar_indexer(key)
# -> 5389     return getitem(key)
#    5391 if isinstance(key, slice):
#    5392     # This case is separated from the conditional above to avoid
#    5393     # pessimization com.is_bool_indexer and ndim checks.
#    5394     return self._getitem_slice(key)
#
# IndexError: index 4 is out of bounds for axis 0 with size 3

# %%
excel_file =r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx"
xl = pd.ExcelFile(excel_file)

# %%
sheet_names = xl.sheet_names
print(sheet_names)
# Out:
# ['1.DERS', '2.DERS', '3.DERS', '4.DERS', '5.DERS', '6.DERS', 'EKLER']

# %%
dfs = []
for sheet_name in sheet_names:
    df = xl.parse(sheet_name)
    dfs.append(df)

# %%
dfs
# Out:
# [    Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      50         NaN
#  1      23582                 ALİ DOST                      50         NaN
#  2      23451             AYLİN YILDIZ                      50         NaN
#  3      23457            AYSU YILDIRIM                      50         NaN
#  4      23570           BAVER AYYILDIZ                      50         NaN
#  5      23469               BULUT AZAK                      38         NaN
#  6      23596         CEMAL CAN ARSLAN                      42         NaN
#  7      23471             DİLAN ERTUNÇ                      50         NaN
#  8      23459              ENGİN AYVAT                      50         NaN
#  9      23198              ERDAL ŞAHAN                       0         NaN
#  10     23458           ERTUĞRUL AYDIN                      46         NaN
#  11     23455             FADİME SAÇAR                      50         NaN
#  12     23450               FARUK OKAY                      50         NaN
#  13     23193          FATİH KARADİKEN                      46         NaN
#  14     19031             FURKAN ŞAHİN                      50         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  16     23462            HAKAN ERTİNGÜ                      50         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23472            İBRAHİM YAŞAR                      40         NaN
#  19     23456              İSHAK ÖZBEK                      50         NaN
#  20     23448        KAAN MAHMUT MACAR                      50         NaN
#  21     23196              KÜBRA GÖKÇE                      50         NaN
#  22     23467            MERVE NUR KUŞ                      50         NaN
#  23     23465             MESUT TEKELİ                      46         NaN
#  24     23470       MİRZA MEHMET YÜCEL                      50         NaN
#  25     23581      MUHAMMET EMİN KESİK                      50         NaN
#  26     23330       MUHAMMET KARADUMAN                      50         NaN
#  27     23449   MUHAMMET LÜTFİ BAŞBOĞA                      46         NaN
#  28     23138        MUHAMMET YILDIRIM                      50         NaN
#  29     23464            MUKADDER KENT                      50         NaN
#  30     23452         MUSA OZAN PATACI                      50         NaN
#  31     23136              OKTAY AYANA                      46         NaN
#  32     23453            ÖMER BOSTANCI                      30         NaN
#  33     23195            ÖMER YILDIRIM                      50         NaN
#  34     23132              ÖZCAN ÇAKIR                      50         NaN
#  35     23463            SERDAR YAZICI                      50         NaN
#  36     23460         SERHAT ÇETİNKAYA                      50         NaN
#  37     23194               SEYDİ SARI                      50         NaN
#  38     23473            ŞAHİN TAŞKAYA                      38         NaN
#  39     23580                ŞEYDA ÖRS                      50         NaN
#  40     23197                TANER HAN                      50         NaN
#  41     23454          TANER HANIMOĞLU                      46         NaN
#  42     23461          TARIK YİĞİTBAŞI                      50         NaN
#  43     23273              TUĞÇE DOĞAN                      50         NaN
#  44     23134              EMRAH KÜÇÜK                       0         NaN
#  45     23135           FETHİYE YILMAZ                       0         NaN
#  46     23272             ÇETİN ÇELEBİ                       0         NaN
#  47     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  48     23587                 OKAN GÖK                       0         NaN
#  49     23588              TURGAY KAYA                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0                  NaN
#  1                  NaN
#  2   DERS SÜRESİ 51 DK.
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      54         NaN
#  1      23582                 ALİ DOST                      42         NaN
#  2      23451             AYLİN YILDIZ                      54         NaN
#  3      23457            AYSU YILDIRIM                      54         NaN
#  4      23570           BAVER AYYILDIZ                      38         NaN
#  5      23469               BULUT AZAK                      54         NaN
#  6      23596         CEMAL CAN ARSLAN                      48         NaN
#  7      23471             DİLAN ERTUNÇ                      54         NaN
#  8      23459              ENGİN AYVAT                      54         NaN
#  9      23198              ERDAL ŞAHAN                      36         NaN
#  10     23458           ERTUĞRUL AYDIN                      54         NaN
#  11     23455             FADİME SAÇAR                      54         NaN
#  12     23450               FARUK OKAY                      48         NaN
#  13     23193          FATİH KARADİKEN                      54         NaN
#  14     19031             FURKAN ŞAHİN                      54         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      54         NaN
#  16     23462            HAKAN ERTİNGÜ                      54         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23456              İSHAK ÖZBEK                      50         NaN
#  19     23448        KAAN MAHMUT MACAR                      54         NaN
#  20     23196              KÜBRA GÖKÇE                      54         NaN
#  21     23467            MERVE NUR KUŞ                      54         NaN
#  22     23465             MESUT TEKELİ                      48         NaN
#  23     23581      MUHAMMET EMİN KESİK                      54         NaN
#  24     23330       MUHAMMET KARADUMAN                      48         NaN
#  25     23449   MUHAMMET LÜTFİ BAŞBOĞA                      22         NaN
#  26     23138        MUHAMMET YILDIRIM                      54         NaN
#  27     23464            MUKADDER KENT                      54         NaN
#  28     23452         MUSA OZAN PATACI                      54         NaN
#  29     23136              OKTAY AYANA                      54         NaN
#  30     23453            ÖMER BOSTANCI                      46         NaN
#  31     23195            ÖMER YILDIRIM                      54         NaN
#  32     23132              ÖZCAN ÇAKIR                      54         NaN
#  33     23463            SERDAR YAZICI                      54         NaN
#  34     23460         SERHAT ÇETİNKAYA                      54         NaN
#  35     23194               SEYDİ SARI                      54         NaN
#  36     23473            ŞAHİN TAŞKAYA                      34         NaN
#  37     23580                ŞEYDA ÖRS                      54         NaN
#  38     23197                TANER HAN                      54         NaN
#  39     23454          TANER HANIMOĞLU                      46         NaN
#  40     23461          TARIK YİĞİTBAŞI                      54         NaN
#  41     23273              TUĞÇE DOĞAN                      54         NaN
#  42     23134              EMRAH KÜÇÜK                       0         NaN
#  43     23135           FETHİYE YILMAZ                       0         NaN
#  44     23272             ÇETİN ÇELEBİ                       0         NaN
#  45     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  46     23587                 OKAN GÖK                       0         NaN
#  47     23588              TURGAY KAYA                       0         NaN
#  48     23470       MİRZA MEHMET YÜCEL                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 54 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      46         NaN
#  1      23451             AYLİN YILDIZ                      50         NaN
#  2      23457            AYSU YILDIRIM                      50         NaN
#  3      23570           BAVER AYYILDIZ                      44         NaN
#  4      23469               BULUT AZAK                      32         NaN
#  5      23596         CEMAL CAN ARSLAN                      46         NaN
#  6      23471             DİLAN ERTUNÇ                      38         NaN
#  7      23459              ENGİN AYVAT                      50         NaN
#  8      23198              ERDAL ŞAHAN                      50         NaN
#  9      23458           ERTUĞRUL AYDIN                      50         NaN
#  10     23455             FADİME SAÇAR                      50         NaN
#  11     23450               FARUK OKAY                      46         NaN
#  12     23193          FATİH KARADİKEN                      50         NaN
#  13     19031             FURKAN ŞAHİN                      50         NaN
#  14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  15     23462            HAKAN ERTİNGÜ                      50         NaN
#  16     23139      HÜSEYİN KEVENCİOĞLU                      40         NaN
#  17     23456              İSHAK ÖZBEK                      50         NaN
#  18     23448        KAAN MAHMUT MACAR                      50         NaN
#  19     23196              KÜBRA GÖKÇE                      50         NaN
#  20     23467            MERVE NUR KUŞ                      50         NaN
#  21     23465             MESUT TEKELİ                      46         NaN
#  22     23470       MİRZA MEHMET YÜCEL                      46         NaN
#  23     23581      MUHAMMET EMİN KESİK                      50         NaN
#  24     23330       MUHAMMET KARADUMAN                      28         NaN
#  25     23138        MUHAMMET YILDIRIM                      46         NaN
#  26     23464            MUKADDER KENT                      50         NaN
#  27     23452         MUSA OZAN PATACI                      50         NaN
#  28     23136              OKTAY AYANA                      46         NaN
#  29     23453            ÖMER BOSTANCI                      36         NaN
#  30     23195            ÖMER YILDIRIM                      50         NaN
#  31     23132              ÖZCAN ÇAKIR                      46         NaN
#  32     23463            SERDAR YAZICI                      50         NaN
#  33     23460         SERHAT ÇETİNKAYA                      32         NaN
#  34     23194               SEYDİ SARI                      38         NaN
#  35     23473            ŞAHİN TAŞKAYA                      46         NaN
#  36     23580                ŞEYDA ÖRS                      50         NaN
#  37     23197                TANER HAN                      50         NaN
#  38     23454          TANER HANIMOĞLU                      36         NaN
#  39     23461          TARIK YİĞİTBAŞI                      50         NaN
#  40     23273              TUĞÇE DOĞAN                      38         NaN
#  41     23134              EMRAH KÜÇÜK                       0         NaN
#  42     23135           FETHİYE YILMAZ                       0         NaN
#  43     23272             ÇETİN ÇELEBİ                       0         NaN
#  44     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  45     23449   MUHAMMET LÜTFİ BAŞBOĞA                       0         NaN
#  46     23582                 ALİ DOST                       0         NaN
#  47     23587                 OKAN GÖK                       0         NaN
#  48     23588              TURGAY KAYA                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 51 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      46         NaN
#  3      23457               AYSU YILDIRIM                      48         NaN
#  4      23570              BAVER AYYILDIZ                      44         NaN
#  5      23469                  BULUT AZAK                      30         NaN
#  6      23596            CEMAL CAN ARSLAN                      42         NaN
#  7      23471                DİLAN ERTUNÇ                      40         NaN
#  8      23459                 ENGİN AYVAT                      48         NaN
#  9      23198                 ERDAL ŞAHAN                      48         NaN
#  10     23458              ERTUĞRUL AYDIN                      48         NaN
#  11     23455                FADİME SAÇAR                      44         NaN
#  12     23450                  FARUK OKAY                      46         NaN
#  13     23193             FATİH KARADİKEN                      28         NaN
#  14     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      42         NaN
#  15     23462               HAKAN ERTİNGÜ                      46         NaN
#  16     23139         HÜSEYİN KEVENCİOĞLU                      18         NaN
#  17     23472               İBRAHİM YAŞAR                      24         NaN
#  18     23456                 İSHAK ÖZBEK                      40         NaN
#  19     23448           KAAN MAHMUT MACAR                      48         NaN
#  20     20676                KEZBAN CANER                      30         NaN
#  21     23196                 KÜBRA GÖKÇE                      46         NaN
#  22     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      32         NaN
#  23     23467               MERVE NUR KUŞ                      44         NaN
#  24     23465                MESUT TEKELİ                      46         NaN
#  25     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  26     23581         MUHAMMET EMİN KESİK                      48         NaN
#  27     23330          MUHAMMET KARADUMAN                      42         NaN
#  28     23449      MUHAMMET LÜTFİ BAŞBOĞA                      14         NaN
#  29     23138           MUHAMMET YILDIRIM                      18         NaN
#  30     23464               MUKADDER KENT                      48         NaN
#  31     23452            MUSA OZAN PATACI                      48         NaN
#  32     23136                 OKTAY AYANA                      46         NaN
#  33     23453               ÖMER BOSTANCI                      44         NaN
#  34     23195               ÖMER YILDIRIM                      48         NaN
#  35     23132                 ÖZCAN ÇAKIR                      48         NaN
#  36     23463               SERDAR YAZICI                      48         NaN
#  37     23460            SERHAT ÇETİNKAYA                      48         NaN
#  38     23194                  SEYDİ SARI                      48         NaN
#  39     23473               ŞAHİN TAŞKAYA                      40         NaN
#  40     23580                   ŞEYDA ÖRS                      36         NaN
#  41     23197                   TANER HAN                      48         NaN
#  42     23454             TANER HANIMOĞLU                      42         NaN
#  43     23461             TARIK YİĞİTBAŞI                      48         NaN
#  44     23273                 TUĞÇE DOĞAN                      42         NaN
#  45     23134                 EMRAH KÜÇÜK                       0         NaN
#  46     23135              FETHİYE YILMAZ                       0         NaN
#  47     23272                ÇETİN ÇELEBİ                       0         NaN
#  48     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 30 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      48         NaN
#  3      23570              BAVER AYYILDIZ                      48         NaN
#  4      23469                  BULUT AZAK                      44         NaN
#  5      23596            CEMAL CAN ARSLAN                      44         NaN
#  6      23471                DİLAN ERTUNÇ                      38         NaN
#  7      23459                 ENGİN AYVAT                      48         NaN
#  8      23198                 ERDAL ŞAHAN                      48         NaN
#  9      23458              ERTUĞRUL AYDIN                      48         NaN
#  10     23455                FADİME SAÇAR                      48         NaN
#  11     23450                  FARUK OKAY                      48         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      48         NaN
#  14     23462               HAKAN ERTİNGÜ                      48         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      48         NaN
#  16     23472               İBRAHİM YAŞAR                      32         NaN
#  17     23456                 İSHAK ÖZBEK                      48         NaN
#  18     23448           KAAN MAHMUT MACAR                      48         NaN
#  19     20676                KEZBAN CANER                      48         NaN
#  20     23196                 KÜBRA GÖKÇE                      48         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      48         NaN
#  22     23467               MERVE NUR KUŞ                      48         NaN
#  23     23465                MESUT TEKELİ                      44         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  25     23581         MUHAMMET EMİN KESİK                      48         NaN
#  26     23330          MUHAMMET KARADUMAN                      40         NaN
#  27     23449      MUHAMMET LÜTFİ BAŞBOĞA                      48         NaN
#  28     23138           MUHAMMET YILDIRIM                      48         NaN
#  29     23464               MUKADDER KENT                      48         NaN
#  30     23452            MUSA OZAN PATACI                      48         NaN
#  31     23136                 OKTAY AYANA                      40         NaN
#  32     23453               ÖMER BOSTANCI                      48         NaN
#  33     23195               ÖMER YILDIRIM                      48         NaN
#  34     23132                 ÖZCAN ÇAKIR                      48         NaN
#  35     23463               SERDAR YAZICI                      48         NaN
#  36     23460            SERHAT ÇETİNKAYA                      48         NaN
#  37     23194                  SEYDİ SARI                      44         NaN
#  38     23473               ŞAHİN TAŞKAYA                      40         NaN
#  39     23580                   ŞEYDA ÖRS                      48         NaN
#  40     23197                   TANER HAN                      48         NaN
#  41     23454             TANER HANIMOĞLU                      42         NaN
#  42     23461             TARIK YİĞİTBAŞI                      48         NaN
#  43     23273                 TUĞÇE DOĞAN                      48         NaN
#  44     23134                 EMRAH KÜÇÜK                       0         NaN
#  45     23135              FETHİYE YILMAZ                       0         NaN
#  46     23272                ÇETİN ÇELEBİ                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 49 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      42         NaN
#  1      23582                    ALİ DOST                      42         NaN
#  2      23451                AYLİN YILDIZ                      42         NaN
#  3      23570              BAVER AYYILDIZ                      42         NaN
#  4      23469                  BULUT AZAK                      34         NaN
#  5      23596            CEMAL CAN ARSLAN                      38         NaN
#  6      23471                DİLAN ERTUNÇ                      42         NaN
#  7      23459                 ENGİN AYVAT                      42         NaN
#  8      23198                 ERDAL ŞAHAN                      24         NaN
#  9      23458              ERTUĞRUL AYDIN                      42         NaN
#  10     23455                FADİME SAÇAR                      42         NaN
#  11     23450                  FARUK OKAY                      42         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      38         NaN
#  14     23462               HAKAN ERTİNGÜ                      42         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      42         NaN
#  16     23472               İBRAHİM YAŞAR                      14         NaN
#  17     23456                 İSHAK ÖZBEK                      42         NaN
#  18     23448           KAAN MAHMUT MACAR                      42         NaN
#  19     20676                KEZBAN CANER                      42         NaN
#  20     23196                 KÜBRA GÖKÇE                      42         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      30         NaN
#  22     23467               MERVE NUR KUŞ                      42         NaN
#  23     23465                MESUT TEKELİ                      36         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      42         NaN
#  25     23581         MUHAMMET EMİN KESİK                      42         NaN
#  26     23449      MUHAMMET LÜTFİ BAŞBOĞA                      38         NaN
#  27     23138           MUHAMMET YILDIRIM                      42         NaN
#  28     23464               MUKADDER KENT                      42         NaN
#  29     23452            MUSA OZAN PATACI                      42         NaN
#  30     23136                 OKTAY AYANA                      42         NaN
#  31     23453               ÖMER BOSTANCI                      34         NaN
#  32     23195               ÖMER YILDIRIM                      42         NaN
#  33     23132                 ÖZCAN ÇAKIR                      42         NaN
#  34     23463               SERDAR YAZICI                      42         NaN
#  35     23460            SERHAT ÇETİNKAYA                      42         NaN
#  36     23194                  SEYDİ SARI                      42         NaN
#  37     23473               ŞAHİN TAŞKAYA                      34         NaN
#  38     23580                   ŞEYDA ÖRS                      42         NaN
#  39     23197                   TANER HAN                      42         NaN
#  40     23454             TANER HANIMOĞLU                      12         NaN
#  41     23461             TARIK YİĞİTBAŞI                      42         NaN
#  42     23273                 TUĞÇE DOĞAN                      42         NaN
#  43     23134                 EMRAH KÜÇÜK                       0         NaN
#  44     23135              FETHİYE YILMAZ                       0         NaN
#  45     23272                ÇETİN ÇELEBİ                       0         NaN
#  46     23330          MUHAMMET KARADUMAN                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 43 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#  Empty DataFrame
#  Columns: []
#  Index: []]

# %%
merged_df = pd.concat(dfs, ignore_index=True)

# %%
merged df
# Out:
#   Cell In[112], line 1
#     merged df
#            ^
# SyntaxError: invalid syntax

# %%
merged_df
# Out:
#      Sicil No        Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
# 0       23466  ABDULLAH ASLAN                      50         NaN
# 1       23582        ALİ DOST                      50         NaN
# 2       23451    AYLİN YILDIZ                      50         NaN
# 3       23457   AYSU YILDIRIM                      50         NaN
# 4       23570  BAVER AYYILDIZ                      50         NaN
# ..        ...             ...                     ...         ...
# 309     23457   AYSU YILDIRIM                       0         NaN
# 310     23587        OKAN GÖK                       0         NaN
# 311     23588     TURGAY KAYA                       0         NaN
# 312     23340        ALİ İĞDE                       0         NaN
# 313     19781      ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
# 0                   NaN
# 1                   NaN
# 2    DERS SÜRESİ 51 DK.
# 3                   NaN
# 4                   NaN
# ..                  ...
# 309                 NaN
# 310                 NaN
# 311                 NaN
# 312                 NaN
# 313                 NaN
#
# [314 rows x 5 columns]

# %%
merged_df = dfs[0]  
for df in dfs[1:]:
    merged_df = merged_df.merge(df, on='Sicil No', how='outer')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[115], line 3
#       1 merged_df = dfs[0]
#       2 for df in dfs[1:]:
# ----> 3     merged_df = merged_df.merge(df, on='Sicil No', how='outer')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:2757, in _items_overlap_with_suffix(left, right, suffixes)
#    2755     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756 if dups:
# -> 2757     raise MergeError(
#    2758         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759         f"not allowed.",
#    2760     )
#    2762 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'Unnamed: 3_x', 'Ad Soyad_x', 'Unnamed: 4_x', 'Oturum Süresi (Dakika)_x'} is not allowed.

# %%
grouped_dfs = []
for df in dfs:
    grouped_df = df.groupby('Sicil No').sum().reset_index()
    grouped_dfs.append(grouped_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[116], line 3
#       1 grouped_dfs = []
#       2 for df in dfs:
# ----> 3     grouped_df = df.groupby('Sicil No').sum().reset_index()
#       4     grouped_dfs.append(grouped_df)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Sicil No'

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
dfs
# Out:
# [    Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      50         NaN
#  1      23582                 ALİ DOST                      50         NaN
#  2      23451             AYLİN YILDIZ                      50         NaN
#  3      23457            AYSU YILDIRIM                      50         NaN
#  4      23570           BAVER AYYILDIZ                      50         NaN
#  5      23469               BULUT AZAK                      38         NaN
#  6      23596         CEMAL CAN ARSLAN                      42         NaN
#  7      23471             DİLAN ERTUNÇ                      50         NaN
#  8      23459              ENGİN AYVAT                      50         NaN
#  9      23198              ERDAL ŞAHAN                       0         NaN
#  10     23458           ERTUĞRUL AYDIN                      46         NaN
#  11     23455             FADİME SAÇAR                      50         NaN
#  12     23450               FARUK OKAY                      50         NaN
#  13     23193          FATİH KARADİKEN                      46         NaN
#  14     19031             FURKAN ŞAHİN                      50         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  16     23462            HAKAN ERTİNGÜ                      50         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23472            İBRAHİM YAŞAR                      40         NaN
#  19     23456              İSHAK ÖZBEK                      50         NaN
#  20     23448        KAAN MAHMUT MACAR                      50         NaN
#  21     23196              KÜBRA GÖKÇE                      50         NaN
#  22     23467            MERVE NUR KUŞ                      50         NaN
#  23     23465             MESUT TEKELİ                      46         NaN
#  24     23470       MİRZA MEHMET YÜCEL                      50         NaN
#  25     23581      MUHAMMET EMİN KESİK                      50         NaN
#  26     23330       MUHAMMET KARADUMAN                      50         NaN
#  27     23449   MUHAMMET LÜTFİ BAŞBOĞA                      46         NaN
#  28     23138        MUHAMMET YILDIRIM                      50         NaN
#  29     23464            MUKADDER KENT                      50         NaN
#  30     23452         MUSA OZAN PATACI                      50         NaN
#  31     23136              OKTAY AYANA                      46         NaN
#  32     23453            ÖMER BOSTANCI                      30         NaN
#  33     23195            ÖMER YILDIRIM                      50         NaN
#  34     23132              ÖZCAN ÇAKIR                      50         NaN
#  35     23463            SERDAR YAZICI                      50         NaN
#  36     23460         SERHAT ÇETİNKAYA                      50         NaN
#  37     23194               SEYDİ SARI                      50         NaN
#  38     23473            ŞAHİN TAŞKAYA                      38         NaN
#  39     23580                ŞEYDA ÖRS                      50         NaN
#  40     23197                TANER HAN                      50         NaN
#  41     23454          TANER HANIMOĞLU                      46         NaN
#  42     23461          TARIK YİĞİTBAŞI                      50         NaN
#  43     23273              TUĞÇE DOĞAN                      50         NaN
#  44     23134              EMRAH KÜÇÜK                       0         NaN
#  45     23135           FETHİYE YILMAZ                       0         NaN
#  46     23272             ÇETİN ÇELEBİ                       0         NaN
#  47     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  48     23587                 OKAN GÖK                       0         NaN
#  49     23588              TURGAY KAYA                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0                  NaN
#  1                  NaN
#  2   DERS SÜRESİ 51 DK.
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      54         NaN
#  1      23582                 ALİ DOST                      42         NaN
#  2      23451             AYLİN YILDIZ                      54         NaN
#  3      23457            AYSU YILDIRIM                      54         NaN
#  4      23570           BAVER AYYILDIZ                      38         NaN
#  5      23469               BULUT AZAK                      54         NaN
#  6      23596         CEMAL CAN ARSLAN                      48         NaN
#  7      23471             DİLAN ERTUNÇ                      54         NaN
#  8      23459              ENGİN AYVAT                      54         NaN
#  9      23198              ERDAL ŞAHAN                      36         NaN
#  10     23458           ERTUĞRUL AYDIN                      54         NaN
#  11     23455             FADİME SAÇAR                      54         NaN
#  12     23450               FARUK OKAY                      48         NaN
#  13     23193          FATİH KARADİKEN                      54         NaN
#  14     19031             FURKAN ŞAHİN                      54         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      54         NaN
#  16     23462            HAKAN ERTİNGÜ                      54         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23456              İSHAK ÖZBEK                      50         NaN
#  19     23448        KAAN MAHMUT MACAR                      54         NaN
#  20     23196              KÜBRA GÖKÇE                      54         NaN
#  21     23467            MERVE NUR KUŞ                      54         NaN
#  22     23465             MESUT TEKELİ                      48         NaN
#  23     23581      MUHAMMET EMİN KESİK                      54         NaN
#  24     23330       MUHAMMET KARADUMAN                      48         NaN
#  25     23449   MUHAMMET LÜTFİ BAŞBOĞA                      22         NaN
#  26     23138        MUHAMMET YILDIRIM                      54         NaN
#  27     23464            MUKADDER KENT                      54         NaN
#  28     23452         MUSA OZAN PATACI                      54         NaN
#  29     23136              OKTAY AYANA                      54         NaN
#  30     23453            ÖMER BOSTANCI                      46         NaN
#  31     23195            ÖMER YILDIRIM                      54         NaN
#  32     23132              ÖZCAN ÇAKIR                      54         NaN
#  33     23463            SERDAR YAZICI                      54         NaN
#  34     23460         SERHAT ÇETİNKAYA                      54         NaN
#  35     23194               SEYDİ SARI                      54         NaN
#  36     23473            ŞAHİN TAŞKAYA                      34         NaN
#  37     23580                ŞEYDA ÖRS                      54         NaN
#  38     23197                TANER HAN                      54         NaN
#  39     23454          TANER HANIMOĞLU                      46         NaN
#  40     23461          TARIK YİĞİTBAŞI                      54         NaN
#  41     23273              TUĞÇE DOĞAN                      54         NaN
#  42     23134              EMRAH KÜÇÜK                       0         NaN
#  43     23135           FETHİYE YILMAZ                       0         NaN
#  44     23272             ÇETİN ÇELEBİ                       0         NaN
#  45     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  46     23587                 OKAN GÖK                       0         NaN
#  47     23588              TURGAY KAYA                       0         NaN
#  48     23470       MİRZA MEHMET YÜCEL                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 54 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      46         NaN
#  1      23451             AYLİN YILDIZ                      50         NaN
#  2      23457            AYSU YILDIRIM                      50         NaN
#  3      23570           BAVER AYYILDIZ                      44         NaN
#  4      23469               BULUT AZAK                      32         NaN
#  5      23596         CEMAL CAN ARSLAN                      46         NaN
#  6      23471             DİLAN ERTUNÇ                      38         NaN
#  7      23459              ENGİN AYVAT                      50         NaN
#  8      23198              ERDAL ŞAHAN                      50         NaN
#  9      23458           ERTUĞRUL AYDIN                      50         NaN
#  10     23455             FADİME SAÇAR                      50         NaN
#  11     23450               FARUK OKAY                      46         NaN
#  12     23193          FATİH KARADİKEN                      50         NaN
#  13     19031             FURKAN ŞAHİN                      50         NaN
#  14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  15     23462            HAKAN ERTİNGÜ                      50         NaN
#  16     23139      HÜSEYİN KEVENCİOĞLU                      40         NaN
#  17     23456              İSHAK ÖZBEK                      50         NaN
#  18     23448        KAAN MAHMUT MACAR                      50         NaN
#  19     23196              KÜBRA GÖKÇE                      50         NaN
#  20     23467            MERVE NUR KUŞ                      50         NaN
#  21     23465             MESUT TEKELİ                      46         NaN
#  22     23470       MİRZA MEHMET YÜCEL                      46         NaN
#  23     23581      MUHAMMET EMİN KESİK                      50         NaN
#  24     23330       MUHAMMET KARADUMAN                      28         NaN
#  25     23138        MUHAMMET YILDIRIM                      46         NaN
#  26     23464            MUKADDER KENT                      50         NaN
#  27     23452         MUSA OZAN PATACI                      50         NaN
#  28     23136              OKTAY AYANA                      46         NaN
#  29     23453            ÖMER BOSTANCI                      36         NaN
#  30     23195            ÖMER YILDIRIM                      50         NaN
#  31     23132              ÖZCAN ÇAKIR                      46         NaN
#  32     23463            SERDAR YAZICI                      50         NaN
#  33     23460         SERHAT ÇETİNKAYA                      32         NaN
#  34     23194               SEYDİ SARI                      38         NaN
#  35     23473            ŞAHİN TAŞKAYA                      46         NaN
#  36     23580                ŞEYDA ÖRS                      50         NaN
#  37     23197                TANER HAN                      50         NaN
#  38     23454          TANER HANIMOĞLU                      36         NaN
#  39     23461          TARIK YİĞİTBAŞI                      50         NaN
#  40     23273              TUĞÇE DOĞAN                      38         NaN
#  41     23134              EMRAH KÜÇÜK                       0         NaN
#  42     23135           FETHİYE YILMAZ                       0         NaN
#  43     23272             ÇETİN ÇELEBİ                       0         NaN
#  44     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  45     23449   MUHAMMET LÜTFİ BAŞBOĞA                       0         NaN
#  46     23582                 ALİ DOST                       0         NaN
#  47     23587                 OKAN GÖK                       0         NaN
#  48     23588              TURGAY KAYA                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 51 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      46         NaN
#  3      23457               AYSU YILDIRIM                      48         NaN
#  4      23570              BAVER AYYILDIZ                      44         NaN
#  5      23469                  BULUT AZAK                      30         NaN
#  6      23596            CEMAL CAN ARSLAN                      42         NaN
#  7      23471                DİLAN ERTUNÇ                      40         NaN
#  8      23459                 ENGİN AYVAT                      48         NaN
#  9      23198                 ERDAL ŞAHAN                      48         NaN
#  10     23458              ERTUĞRUL AYDIN                      48         NaN
#  11     23455                FADİME SAÇAR                      44         NaN
#  12     23450                  FARUK OKAY                      46         NaN
#  13     23193             FATİH KARADİKEN                      28         NaN
#  14     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      42         NaN
#  15     23462               HAKAN ERTİNGÜ                      46         NaN
#  16     23139         HÜSEYİN KEVENCİOĞLU                      18         NaN
#  17     23472               İBRAHİM YAŞAR                      24         NaN
#  18     23456                 İSHAK ÖZBEK                      40         NaN
#  19     23448           KAAN MAHMUT MACAR                      48         NaN
#  20     20676                KEZBAN CANER                      30         NaN
#  21     23196                 KÜBRA GÖKÇE                      46         NaN
#  22     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      32         NaN
#  23     23467               MERVE NUR KUŞ                      44         NaN
#  24     23465                MESUT TEKELİ                      46         NaN
#  25     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  26     23581         MUHAMMET EMİN KESİK                      48         NaN
#  27     23330          MUHAMMET KARADUMAN                      42         NaN
#  28     23449      MUHAMMET LÜTFİ BAŞBOĞA                      14         NaN
#  29     23138           MUHAMMET YILDIRIM                      18         NaN
#  30     23464               MUKADDER KENT                      48         NaN
#  31     23452            MUSA OZAN PATACI                      48         NaN
#  32     23136                 OKTAY AYANA                      46         NaN
#  33     23453               ÖMER BOSTANCI                      44         NaN
#  34     23195               ÖMER YILDIRIM                      48         NaN
#  35     23132                 ÖZCAN ÇAKIR                      48         NaN
#  36     23463               SERDAR YAZICI                      48         NaN
#  37     23460            SERHAT ÇETİNKAYA                      48         NaN
#  38     23194                  SEYDİ SARI                      48         NaN
#  39     23473               ŞAHİN TAŞKAYA                      40         NaN
#  40     23580                   ŞEYDA ÖRS                      36         NaN
#  41     23197                   TANER HAN                      48         NaN
#  42     23454             TANER HANIMOĞLU                      42         NaN
#  43     23461             TARIK YİĞİTBAŞI                      48         NaN
#  44     23273                 TUĞÇE DOĞAN                      42         NaN
#  45     23134                 EMRAH KÜÇÜK                       0         NaN
#  46     23135              FETHİYE YILMAZ                       0         NaN
#  47     23272                ÇETİN ÇELEBİ                       0         NaN
#  48     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 30 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      48         NaN
#  3      23570              BAVER AYYILDIZ                      48         NaN
#  4      23469                  BULUT AZAK                      44         NaN
#  5      23596            CEMAL CAN ARSLAN                      44         NaN
#  6      23471                DİLAN ERTUNÇ                      38         NaN
#  7      23459                 ENGİN AYVAT                      48         NaN
#  8      23198                 ERDAL ŞAHAN                      48         NaN
#  9      23458              ERTUĞRUL AYDIN                      48         NaN
#  10     23455                FADİME SAÇAR                      48         NaN
#  11     23450                  FARUK OKAY                      48         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      48         NaN
#  14     23462               HAKAN ERTİNGÜ                      48         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      48         NaN
#  16     23472               İBRAHİM YAŞAR                      32         NaN
#  17     23456                 İSHAK ÖZBEK                      48         NaN
#  18     23448           KAAN MAHMUT MACAR                      48         NaN
#  19     20676                KEZBAN CANER                      48         NaN
#  20     23196                 KÜBRA GÖKÇE                      48         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      48         NaN
#  22     23467               MERVE NUR KUŞ                      48         NaN
#  23     23465                MESUT TEKELİ                      44         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  25     23581         MUHAMMET EMİN KESİK                      48         NaN
#  26     23330          MUHAMMET KARADUMAN                      40         NaN
#  27     23449      MUHAMMET LÜTFİ BAŞBOĞA                      48         NaN
#  28     23138           MUHAMMET YILDIRIM                      48         NaN
#  29     23464               MUKADDER KENT                      48         NaN
#  30     23452            MUSA OZAN PATACI                      48         NaN
#  31     23136                 OKTAY AYANA                      40         NaN
#  32     23453               ÖMER BOSTANCI                      48         NaN
#  33     23195               ÖMER YILDIRIM                      48         NaN
#  34     23132                 ÖZCAN ÇAKIR                      48         NaN
#  35     23463               SERDAR YAZICI                      48         NaN
#  36     23460            SERHAT ÇETİNKAYA                      48         NaN
#  37     23194                  SEYDİ SARI                      44         NaN
#  38     23473               ŞAHİN TAŞKAYA                      40         NaN
#  39     23580                   ŞEYDA ÖRS                      48         NaN
#  40     23197                   TANER HAN                      48         NaN
#  41     23454             TANER HANIMOĞLU                      42         NaN
#  42     23461             TARIK YİĞİTBAŞI                      48         NaN
#  43     23273                 TUĞÇE DOĞAN                      48         NaN
#  44     23134                 EMRAH KÜÇÜK                       0         NaN
#  45     23135              FETHİYE YILMAZ                       0         NaN
#  46     23272                ÇETİN ÇELEBİ                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 49 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      42         NaN
#  1      23582                    ALİ DOST                      42         NaN
#  2      23451                AYLİN YILDIZ                      42         NaN
#  3      23570              BAVER AYYILDIZ                      42         NaN
#  4      23469                  BULUT AZAK                      34         NaN
#  5      23596            CEMAL CAN ARSLAN                      38         NaN
#  6      23471                DİLAN ERTUNÇ                      42         NaN
#  7      23459                 ENGİN AYVAT                      42         NaN
#  8      23198                 ERDAL ŞAHAN                      24         NaN
#  9      23458              ERTUĞRUL AYDIN                      42         NaN
#  10     23455                FADİME SAÇAR                      42         NaN
#  11     23450                  FARUK OKAY                      42         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      38         NaN
#  14     23462               HAKAN ERTİNGÜ                      42         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      42         NaN
#  16     23472               İBRAHİM YAŞAR                      14         NaN
#  17     23456                 İSHAK ÖZBEK                      42         NaN
#  18     23448           KAAN MAHMUT MACAR                      42         NaN
#  19     20676                KEZBAN CANER                      42         NaN
#  20     23196                 KÜBRA GÖKÇE                      42         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      30         NaN
#  22     23467               MERVE NUR KUŞ                      42         NaN
#  23     23465                MESUT TEKELİ                      36         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      42         NaN
#  25     23581         MUHAMMET EMİN KESİK                      42         NaN
#  26     23449      MUHAMMET LÜTFİ BAŞBOĞA                      38         NaN
#  27     23138           MUHAMMET YILDIRIM                      42         NaN
#  28     23464               MUKADDER KENT                      42         NaN
#  29     23452            MUSA OZAN PATACI                      42         NaN
#  30     23136                 OKTAY AYANA                      42         NaN
#  31     23453               ÖMER BOSTANCI                      34         NaN
#  32     23195               ÖMER YILDIRIM                      42         NaN
#  33     23132                 ÖZCAN ÇAKIR                      42         NaN
#  34     23463               SERDAR YAZICI                      42         NaN
#  35     23460            SERHAT ÇETİNKAYA                      42         NaN
#  36     23194                  SEYDİ SARI                      42         NaN
#  37     23473               ŞAHİN TAŞKAYA                      34         NaN
#  38     23580                   ŞEYDA ÖRS                      42         NaN
#  39     23197                   TANER HAN                      42         NaN
#  40     23454             TANER HANIMOĞLU                      12         NaN
#  41     23461             TARIK YİĞİTBAŞI                      42         NaN
#  42     23273                 TUĞÇE DOĞAN                      42         NaN
#  43     23134                 EMRAH KÜÇÜK                       0         NaN
#  44     23135              FETHİYE YILMAZ                       0         NaN
#  45     23272                ÇETİN ÇELEBİ                       0         NaN
#  46     23330          MUHAMMET KARADUMAN                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 43 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#  Empty DataFrame
#  Columns: []
#  Index: []]

# %%
grouped_dfs = []
for df in dfs:
    grouped_df = df.groupby('Sicil No').sum().reset_index()
    grouped_dfs.append(grouped_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[121], line 3
#       1 grouped_dfs = []
#       2 for df in dfs:
# ----> 3     grouped_df = df.groupby('Sicil No').sum().reset_index()
#       4     grouped_dfs.append(grouped_df)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Sicil No'

# %%
file_path = r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx"
df = pd.read_excel(file_path)

# %%
grouped_dfs = []
for df in dfs:
    grouped_df = df.groupby('Sicil No').sum().reset_index()
    grouped_dfs.append(grouped_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 3
#       1 grouped_dfs = []
#       2 for df in dfs:
# ----> 3     grouped_df = df.groupby('Sicil No').sum().reset_index()
#       4     grouped_dfs.append(grouped_df)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Sicil No'

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dfs
# Out:
# [    Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      50         NaN
#  1      23582                 ALİ DOST                      50         NaN
#  2      23451             AYLİN YILDIZ                      50         NaN
#  3      23457            AYSU YILDIRIM                      50         NaN
#  4      23570           BAVER AYYILDIZ                      50         NaN
#  5      23469               BULUT AZAK                      38         NaN
#  6      23596         CEMAL CAN ARSLAN                      42         NaN
#  7      23471             DİLAN ERTUNÇ                      50         NaN
#  8      23459              ENGİN AYVAT                      50         NaN
#  9      23198              ERDAL ŞAHAN                       0         NaN
#  10     23458           ERTUĞRUL AYDIN                      46         NaN
#  11     23455             FADİME SAÇAR                      50         NaN
#  12     23450               FARUK OKAY                      50         NaN
#  13     23193          FATİH KARADİKEN                      46         NaN
#  14     19031             FURKAN ŞAHİN                      50         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  16     23462            HAKAN ERTİNGÜ                      50         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23472            İBRAHİM YAŞAR                      40         NaN
#  19     23456              İSHAK ÖZBEK                      50         NaN
#  20     23448        KAAN MAHMUT MACAR                      50         NaN
#  21     23196              KÜBRA GÖKÇE                      50         NaN
#  22     23467            MERVE NUR KUŞ                      50         NaN
#  23     23465             MESUT TEKELİ                      46         NaN
#  24     23470       MİRZA MEHMET YÜCEL                      50         NaN
#  25     23581      MUHAMMET EMİN KESİK                      50         NaN
#  26     23330       MUHAMMET KARADUMAN                      50         NaN
#  27     23449   MUHAMMET LÜTFİ BAŞBOĞA                      46         NaN
#  28     23138        MUHAMMET YILDIRIM                      50         NaN
#  29     23464            MUKADDER KENT                      50         NaN
#  30     23452         MUSA OZAN PATACI                      50         NaN
#  31     23136              OKTAY AYANA                      46         NaN
#  32     23453            ÖMER BOSTANCI                      30         NaN
#  33     23195            ÖMER YILDIRIM                      50         NaN
#  34     23132              ÖZCAN ÇAKIR                      50         NaN
#  35     23463            SERDAR YAZICI                      50         NaN
#  36     23460         SERHAT ÇETİNKAYA                      50         NaN
#  37     23194               SEYDİ SARI                      50         NaN
#  38     23473            ŞAHİN TAŞKAYA                      38         NaN
#  39     23580                ŞEYDA ÖRS                      50         NaN
#  40     23197                TANER HAN                      50         NaN
#  41     23454          TANER HANIMOĞLU                      46         NaN
#  42     23461          TARIK YİĞİTBAŞI                      50         NaN
#  43     23273              TUĞÇE DOĞAN                      50         NaN
#  44     23134              EMRAH KÜÇÜK                       0         NaN
#  45     23135           FETHİYE YILMAZ                       0         NaN
#  46     23272             ÇETİN ÇELEBİ                       0         NaN
#  47     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  48     23587                 OKAN GÖK                       0         NaN
#  49     23588              TURGAY KAYA                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0                  NaN
#  1                  NaN
#  2   DERS SÜRESİ 51 DK.
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      54         NaN
#  1      23582                 ALİ DOST                      42         NaN
#  2      23451             AYLİN YILDIZ                      54         NaN
#  3      23457            AYSU YILDIRIM                      54         NaN
#  4      23570           BAVER AYYILDIZ                      38         NaN
#  5      23469               BULUT AZAK                      54         NaN
#  6      23596         CEMAL CAN ARSLAN                      48         NaN
#  7      23471             DİLAN ERTUNÇ                      54         NaN
#  8      23459              ENGİN AYVAT                      54         NaN
#  9      23198              ERDAL ŞAHAN                      36         NaN
#  10     23458           ERTUĞRUL AYDIN                      54         NaN
#  11     23455             FADİME SAÇAR                      54         NaN
#  12     23450               FARUK OKAY                      48         NaN
#  13     23193          FATİH KARADİKEN                      54         NaN
#  14     19031             FURKAN ŞAHİN                      54         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      54         NaN
#  16     23462            HAKAN ERTİNGÜ                      54         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23456              İSHAK ÖZBEK                      50         NaN
#  19     23448        KAAN MAHMUT MACAR                      54         NaN
#  20     23196              KÜBRA GÖKÇE                      54         NaN
#  21     23467            MERVE NUR KUŞ                      54         NaN
#  22     23465             MESUT TEKELİ                      48         NaN
#  23     23581      MUHAMMET EMİN KESİK                      54         NaN
#  24     23330       MUHAMMET KARADUMAN                      48         NaN
#  25     23449   MUHAMMET LÜTFİ BAŞBOĞA                      22         NaN
#  26     23138        MUHAMMET YILDIRIM                      54         NaN
#  27     23464            MUKADDER KENT                      54         NaN
#  28     23452         MUSA OZAN PATACI                      54         NaN
#  29     23136              OKTAY AYANA                      54         NaN
#  30     23453            ÖMER BOSTANCI                      46         NaN
#  31     23195            ÖMER YILDIRIM                      54         NaN
#  32     23132              ÖZCAN ÇAKIR                      54         NaN
#  33     23463            SERDAR YAZICI                      54         NaN
#  34     23460         SERHAT ÇETİNKAYA                      54         NaN
#  35     23194               SEYDİ SARI                      54         NaN
#  36     23473            ŞAHİN TAŞKAYA                      34         NaN
#  37     23580                ŞEYDA ÖRS                      54         NaN
#  38     23197                TANER HAN                      54         NaN
#  39     23454          TANER HANIMOĞLU                      46         NaN
#  40     23461          TARIK YİĞİTBAŞI                      54         NaN
#  41     23273              TUĞÇE DOĞAN                      54         NaN
#  42     23134              EMRAH KÜÇÜK                       0         NaN
#  43     23135           FETHİYE YILMAZ                       0         NaN
#  44     23272             ÇETİN ÇELEBİ                       0         NaN
#  45     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  46     23587                 OKAN GÖK                       0         NaN
#  47     23588              TURGAY KAYA                       0         NaN
#  48     23470       MİRZA MEHMET YÜCEL                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 54 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      46         NaN
#  1      23451             AYLİN YILDIZ                      50         NaN
#  2      23457            AYSU YILDIRIM                      50         NaN
#  3      23570           BAVER AYYILDIZ                      44         NaN
#  4      23469               BULUT AZAK                      32         NaN
#  5      23596         CEMAL CAN ARSLAN                      46         NaN
#  6      23471             DİLAN ERTUNÇ                      38         NaN
#  7      23459              ENGİN AYVAT                      50         NaN
#  8      23198              ERDAL ŞAHAN                      50         NaN
#  9      23458           ERTUĞRUL AYDIN                      50         NaN
#  10     23455             FADİME SAÇAR                      50         NaN
#  11     23450               FARUK OKAY                      46         NaN
#  12     23193          FATİH KARADİKEN                      50         NaN
#  13     19031             FURKAN ŞAHİN                      50         NaN
#  14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  15     23462            HAKAN ERTİNGÜ                      50         NaN
#  16     23139      HÜSEYİN KEVENCİOĞLU                      40         NaN
#  17     23456              İSHAK ÖZBEK                      50         NaN
#  18     23448        KAAN MAHMUT MACAR                      50         NaN
#  19     23196              KÜBRA GÖKÇE                      50         NaN
#  20     23467            MERVE NUR KUŞ                      50         NaN
#  21     23465             MESUT TEKELİ                      46         NaN
#  22     23470       MİRZA MEHMET YÜCEL                      46         NaN
#  23     23581      MUHAMMET EMİN KESİK                      50         NaN
#  24     23330       MUHAMMET KARADUMAN                      28         NaN
#  25     23138        MUHAMMET YILDIRIM                      46         NaN
#  26     23464            MUKADDER KENT                      50         NaN
#  27     23452         MUSA OZAN PATACI                      50         NaN
#  28     23136              OKTAY AYANA                      46         NaN
#  29     23453            ÖMER BOSTANCI                      36         NaN
#  30     23195            ÖMER YILDIRIM                      50         NaN
#  31     23132              ÖZCAN ÇAKIR                      46         NaN
#  32     23463            SERDAR YAZICI                      50         NaN
#  33     23460         SERHAT ÇETİNKAYA                      32         NaN
#  34     23194               SEYDİ SARI                      38         NaN
#  35     23473            ŞAHİN TAŞKAYA                      46         NaN
#  36     23580                ŞEYDA ÖRS                      50         NaN
#  37     23197                TANER HAN                      50         NaN
#  38     23454          TANER HANIMOĞLU                      36         NaN
#  39     23461          TARIK YİĞİTBAŞI                      50         NaN
#  40     23273              TUĞÇE DOĞAN                      38         NaN
#  41     23134              EMRAH KÜÇÜK                       0         NaN
#  42     23135           FETHİYE YILMAZ                       0         NaN
#  43     23272             ÇETİN ÇELEBİ                       0         NaN
#  44     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  45     23449   MUHAMMET LÜTFİ BAŞBOĞA                       0         NaN
#  46     23582                 ALİ DOST                       0         NaN
#  47     23587                 OKAN GÖK                       0         NaN
#  48     23588              TURGAY KAYA                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 51 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      46         NaN
#  3      23457               AYSU YILDIRIM                      48         NaN
#  4      23570              BAVER AYYILDIZ                      44         NaN
#  5      23469                  BULUT AZAK                      30         NaN
#  6      23596            CEMAL CAN ARSLAN                      42         NaN
#  7      23471                DİLAN ERTUNÇ                      40         NaN
#  8      23459                 ENGİN AYVAT                      48         NaN
#  9      23198                 ERDAL ŞAHAN                      48         NaN
#  10     23458              ERTUĞRUL AYDIN                      48         NaN
#  11     23455                FADİME SAÇAR                      44         NaN
#  12     23450                  FARUK OKAY                      46         NaN
#  13     23193             FATİH KARADİKEN                      28         NaN
#  14     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      42         NaN
#  15     23462               HAKAN ERTİNGÜ                      46         NaN
#  16     23139         HÜSEYİN KEVENCİOĞLU                      18         NaN
#  17     23472               İBRAHİM YAŞAR                      24         NaN
#  18     23456                 İSHAK ÖZBEK                      40         NaN
#  19     23448           KAAN MAHMUT MACAR                      48         NaN
#  20     20676                KEZBAN CANER                      30         NaN
#  21     23196                 KÜBRA GÖKÇE                      46         NaN
#  22     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      32         NaN
#  23     23467               MERVE NUR KUŞ                      44         NaN
#  24     23465                MESUT TEKELİ                      46         NaN
#  25     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  26     23581         MUHAMMET EMİN KESİK                      48         NaN
#  27     23330          MUHAMMET KARADUMAN                      42         NaN
#  28     23449      MUHAMMET LÜTFİ BAŞBOĞA                      14         NaN
#  29     23138           MUHAMMET YILDIRIM                      18         NaN
#  30     23464               MUKADDER KENT                      48         NaN
#  31     23452            MUSA OZAN PATACI                      48         NaN
#  32     23136                 OKTAY AYANA                      46         NaN
#  33     23453               ÖMER BOSTANCI                      44         NaN
#  34     23195               ÖMER YILDIRIM                      48         NaN
#  35     23132                 ÖZCAN ÇAKIR                      48         NaN
#  36     23463               SERDAR YAZICI                      48         NaN
#  37     23460            SERHAT ÇETİNKAYA                      48         NaN
#  38     23194                  SEYDİ SARI                      48         NaN
#  39     23473               ŞAHİN TAŞKAYA                      40         NaN
#  40     23580                   ŞEYDA ÖRS                      36         NaN
#  41     23197                   TANER HAN                      48         NaN
#  42     23454             TANER HANIMOĞLU                      42         NaN
#  43     23461             TARIK YİĞİTBAŞI                      48         NaN
#  44     23273                 TUĞÇE DOĞAN                      42         NaN
#  45     23134                 EMRAH KÜÇÜK                       0         NaN
#  46     23135              FETHİYE YILMAZ                       0         NaN
#  47     23272                ÇETİN ÇELEBİ                       0         NaN
#  48     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 30 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      48         NaN
#  3      23570              BAVER AYYILDIZ                      48         NaN
#  4      23469                  BULUT AZAK                      44         NaN
#  5      23596            CEMAL CAN ARSLAN                      44         NaN
#  6      23471                DİLAN ERTUNÇ                      38         NaN
#  7      23459                 ENGİN AYVAT                      48         NaN
#  8      23198                 ERDAL ŞAHAN                      48         NaN
#  9      23458              ERTUĞRUL AYDIN                      48         NaN
#  10     23455                FADİME SAÇAR                      48         NaN
#  11     23450                  FARUK OKAY                      48         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      48         NaN
#  14     23462               HAKAN ERTİNGÜ                      48         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      48         NaN
#  16     23472               İBRAHİM YAŞAR                      32         NaN
#  17     23456                 İSHAK ÖZBEK                      48         NaN
#  18     23448           KAAN MAHMUT MACAR                      48         NaN
#  19     20676                KEZBAN CANER                      48         NaN
#  20     23196                 KÜBRA GÖKÇE                      48         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      48         NaN
#  22     23467               MERVE NUR KUŞ                      48         NaN
#  23     23465                MESUT TEKELİ                      44         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  25     23581         MUHAMMET EMİN KESİK                      48         NaN
#  26     23330          MUHAMMET KARADUMAN                      40         NaN
#  27     23449      MUHAMMET LÜTFİ BAŞBOĞA                      48         NaN
#  28     23138           MUHAMMET YILDIRIM                      48         NaN
#  29     23464               MUKADDER KENT                      48         NaN
#  30     23452            MUSA OZAN PATACI                      48         NaN
#  31     23136                 OKTAY AYANA                      40         NaN
#  32     23453               ÖMER BOSTANCI                      48         NaN
#  33     23195               ÖMER YILDIRIM                      48         NaN
#  34     23132                 ÖZCAN ÇAKIR                      48         NaN
#  35     23463               SERDAR YAZICI                      48         NaN
#  36     23460            SERHAT ÇETİNKAYA                      48         NaN
#  37     23194                  SEYDİ SARI                      44         NaN
#  38     23473               ŞAHİN TAŞKAYA                      40         NaN
#  39     23580                   ŞEYDA ÖRS                      48         NaN
#  40     23197                   TANER HAN                      48         NaN
#  41     23454             TANER HANIMOĞLU                      42         NaN
#  42     23461             TARIK YİĞİTBAŞI                      48         NaN
#  43     23273                 TUĞÇE DOĞAN                      48         NaN
#  44     23134                 EMRAH KÜÇÜK                       0         NaN
#  45     23135              FETHİYE YILMAZ                       0         NaN
#  46     23272                ÇETİN ÇELEBİ                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 49 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      42         NaN
#  1      23582                    ALİ DOST                      42         NaN
#  2      23451                AYLİN YILDIZ                      42         NaN
#  3      23570              BAVER AYYILDIZ                      42         NaN
#  4      23469                  BULUT AZAK                      34         NaN
#  5      23596            CEMAL CAN ARSLAN                      38         NaN
#  6      23471                DİLAN ERTUNÇ                      42         NaN
#  7      23459                 ENGİN AYVAT                      42         NaN
#  8      23198                 ERDAL ŞAHAN                      24         NaN
#  9      23458              ERTUĞRUL AYDIN                      42         NaN
#  10     23455                FADİME SAÇAR                      42         NaN
#  11     23450                  FARUK OKAY                      42         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      38         NaN
#  14     23462               HAKAN ERTİNGÜ                      42         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      42         NaN
#  16     23472               İBRAHİM YAŞAR                      14         NaN
#  17     23456                 İSHAK ÖZBEK                      42         NaN
#  18     23448           KAAN MAHMUT MACAR                      42         NaN
#  19     20676                KEZBAN CANER                      42         NaN
#  20     23196                 KÜBRA GÖKÇE                      42         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      30         NaN
#  22     23467               MERVE NUR KUŞ                      42         NaN
#  23     23465                MESUT TEKELİ                      36         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      42         NaN
#  25     23581         MUHAMMET EMİN KESİK                      42         NaN
#  26     23449      MUHAMMET LÜTFİ BAŞBOĞA                      38         NaN
#  27     23138           MUHAMMET YILDIRIM                      42         NaN
#  28     23464               MUKADDER KENT                      42         NaN
#  29     23452            MUSA OZAN PATACI                      42         NaN
#  30     23136                 OKTAY AYANA                      42         NaN
#  31     23453               ÖMER BOSTANCI                      34         NaN
#  32     23195               ÖMER YILDIRIM                      42         NaN
#  33     23132                 ÖZCAN ÇAKIR                      42         NaN
#  34     23463               SERDAR YAZICI                      42         NaN
#  35     23460            SERHAT ÇETİNKAYA                      42         NaN
#  36     23194                  SEYDİ SARI                      42         NaN
#  37     23473               ŞAHİN TAŞKAYA                      34         NaN
#  38     23580                   ŞEYDA ÖRS                      42         NaN
#  39     23197                   TANER HAN                      42         NaN
#  40     23454             TANER HANIMOĞLU                      12         NaN
#  41     23461             TARIK YİĞİTBAŞI                      42         NaN
#  42     23273                 TUĞÇE DOĞAN                      42         NaN
#  43     23134                 EMRAH KÜÇÜK                       0         NaN
#  44     23135              FETHİYE YILMAZ                       0         NaN
#  45     23272                ÇETİN ÇELEBİ                       0         NaN
#  46     23330          MUHAMMET KARADUMAN                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 43 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#  Empty DataFrame
#  Columns: []
#  Index: []]

# %%
dfs
# Out:
# [    Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      50         NaN
#  1      23582                 ALİ DOST                      50         NaN
#  2      23451             AYLİN YILDIZ                      50         NaN
#  3      23457            AYSU YILDIRIM                      50         NaN
#  4      23570           BAVER AYYILDIZ                      50         NaN
#  5      23469               BULUT AZAK                      38         NaN
#  6      23596         CEMAL CAN ARSLAN                      42         NaN
#  7      23471             DİLAN ERTUNÇ                      50         NaN
#  8      23459              ENGİN AYVAT                      50         NaN
#  9      23198              ERDAL ŞAHAN                       0         NaN
#  10     23458           ERTUĞRUL AYDIN                      46         NaN
#  11     23455             FADİME SAÇAR                      50         NaN
#  12     23450               FARUK OKAY                      50         NaN
#  13     23193          FATİH KARADİKEN                      46         NaN
#  14     19031             FURKAN ŞAHİN                      50         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  16     23462            HAKAN ERTİNGÜ                      50         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23472            İBRAHİM YAŞAR                      40         NaN
#  19     23456              İSHAK ÖZBEK                      50         NaN
#  20     23448        KAAN MAHMUT MACAR                      50         NaN
#  21     23196              KÜBRA GÖKÇE                      50         NaN
#  22     23467            MERVE NUR KUŞ                      50         NaN
#  23     23465             MESUT TEKELİ                      46         NaN
#  24     23470       MİRZA MEHMET YÜCEL                      50         NaN
#  25     23581      MUHAMMET EMİN KESİK                      50         NaN
#  26     23330       MUHAMMET KARADUMAN                      50         NaN
#  27     23449   MUHAMMET LÜTFİ BAŞBOĞA                      46         NaN
#  28     23138        MUHAMMET YILDIRIM                      50         NaN
#  29     23464            MUKADDER KENT                      50         NaN
#  30     23452         MUSA OZAN PATACI                      50         NaN
#  31     23136              OKTAY AYANA                      46         NaN
#  32     23453            ÖMER BOSTANCI                      30         NaN
#  33     23195            ÖMER YILDIRIM                      50         NaN
#  34     23132              ÖZCAN ÇAKIR                      50         NaN
#  35     23463            SERDAR YAZICI                      50         NaN
#  36     23460         SERHAT ÇETİNKAYA                      50         NaN
#  37     23194               SEYDİ SARI                      50         NaN
#  38     23473            ŞAHİN TAŞKAYA                      38         NaN
#  39     23580                ŞEYDA ÖRS                      50         NaN
#  40     23197                TANER HAN                      50         NaN
#  41     23454          TANER HANIMOĞLU                      46         NaN
#  42     23461          TARIK YİĞİTBAŞI                      50         NaN
#  43     23273              TUĞÇE DOĞAN                      50         NaN
#  44     23134              EMRAH KÜÇÜK                       0         NaN
#  45     23135           FETHİYE YILMAZ                       0         NaN
#  46     23272             ÇETİN ÇELEBİ                       0         NaN
#  47     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  48     23587                 OKAN GÖK                       0         NaN
#  49     23588              TURGAY KAYA                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0                  NaN
#  1                  NaN
#  2   DERS SÜRESİ 51 DK.
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      54         NaN
#  1      23582                 ALİ DOST                      42         NaN
#  2      23451             AYLİN YILDIZ                      54         NaN
#  3      23457            AYSU YILDIRIM                      54         NaN
#  4      23570           BAVER AYYILDIZ                      38         NaN
#  5      23469               BULUT AZAK                      54         NaN
#  6      23596         CEMAL CAN ARSLAN                      48         NaN
#  7      23471             DİLAN ERTUNÇ                      54         NaN
#  8      23459              ENGİN AYVAT                      54         NaN
#  9      23198              ERDAL ŞAHAN                      36         NaN
#  10     23458           ERTUĞRUL AYDIN                      54         NaN
#  11     23455             FADİME SAÇAR                      54         NaN
#  12     23450               FARUK OKAY                      48         NaN
#  13     23193          FATİH KARADİKEN                      54         NaN
#  14     19031             FURKAN ŞAHİN                      54         NaN
#  15     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      54         NaN
#  16     23462            HAKAN ERTİNGÜ                      54         NaN
#  17     23139      HÜSEYİN KEVENCİOĞLU                      44         NaN
#  18     23456              İSHAK ÖZBEK                      50         NaN
#  19     23448        KAAN MAHMUT MACAR                      54         NaN
#  20     23196              KÜBRA GÖKÇE                      54         NaN
#  21     23467            MERVE NUR KUŞ                      54         NaN
#  22     23465             MESUT TEKELİ                      48         NaN
#  23     23581      MUHAMMET EMİN KESİK                      54         NaN
#  24     23330       MUHAMMET KARADUMAN                      48         NaN
#  25     23449   MUHAMMET LÜTFİ BAŞBOĞA                      22         NaN
#  26     23138        MUHAMMET YILDIRIM                      54         NaN
#  27     23464            MUKADDER KENT                      54         NaN
#  28     23452         MUSA OZAN PATACI                      54         NaN
#  29     23136              OKTAY AYANA                      54         NaN
#  30     23453            ÖMER BOSTANCI                      46         NaN
#  31     23195            ÖMER YILDIRIM                      54         NaN
#  32     23132              ÖZCAN ÇAKIR                      54         NaN
#  33     23463            SERDAR YAZICI                      54         NaN
#  34     23460         SERHAT ÇETİNKAYA                      54         NaN
#  35     23194               SEYDİ SARI                      54         NaN
#  36     23473            ŞAHİN TAŞKAYA                      34         NaN
#  37     23580                ŞEYDA ÖRS                      54         NaN
#  38     23197                TANER HAN                      54         NaN
#  39     23454          TANER HANIMOĞLU                      46         NaN
#  40     23461          TARIK YİĞİTBAŞI                      54         NaN
#  41     23273              TUĞÇE DOĞAN                      54         NaN
#  42     23134              EMRAH KÜÇÜK                       0         NaN
#  43     23135           FETHİYE YILMAZ                       0         NaN
#  44     23272             ÇETİN ÇELEBİ                       0         NaN
#  45     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  46     23587                 OKAN GÖK                       0         NaN
#  47     23588              TURGAY KAYA                       0         NaN
#  48     23470       MİRZA MEHMET YÜCEL                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 54 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                 Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466           ABDULLAH ASLAN                      46         NaN
#  1      23451             AYLİN YILDIZ                      50         NaN
#  2      23457            AYSU YILDIRIM                      50         NaN
#  3      23570           BAVER AYYILDIZ                      44         NaN
#  4      23469               BULUT AZAK                      32         NaN
#  5      23596         CEMAL CAN ARSLAN                      46         NaN
#  6      23471             DİLAN ERTUNÇ                      38         NaN
#  7      23459              ENGİN AYVAT                      50         NaN
#  8      23198              ERDAL ŞAHAN                      50         NaN
#  9      23458           ERTUĞRUL AYDIN                      50         NaN
#  10     23455             FADİME SAÇAR                      50         NaN
#  11     23450               FARUK OKAY                      46         NaN
#  12     23193          FATİH KARADİKEN                      50         NaN
#  13     19031             FURKAN ŞAHİN                      50         NaN
#  14     23468  GÜRHAN MUSTAFA ÇINARBAŞ                      50         NaN
#  15     23462            HAKAN ERTİNGÜ                      50         NaN
#  16     23139      HÜSEYİN KEVENCİOĞLU                      40         NaN
#  17     23456              İSHAK ÖZBEK                      50         NaN
#  18     23448        KAAN MAHMUT MACAR                      50         NaN
#  19     23196              KÜBRA GÖKÇE                      50         NaN
#  20     23467            MERVE NUR KUŞ                      50         NaN
#  21     23465             MESUT TEKELİ                      46         NaN
#  22     23470       MİRZA MEHMET YÜCEL                      46         NaN
#  23     23581      MUHAMMET EMİN KESİK                      50         NaN
#  24     23330       MUHAMMET KARADUMAN                      28         NaN
#  25     23138        MUHAMMET YILDIRIM                      46         NaN
#  26     23464            MUKADDER KENT                      50         NaN
#  27     23452         MUSA OZAN PATACI                      50         NaN
#  28     23136              OKTAY AYANA                      46         NaN
#  29     23453            ÖMER BOSTANCI                      36         NaN
#  30     23195            ÖMER YILDIRIM                      50         NaN
#  31     23132              ÖZCAN ÇAKIR                      46         NaN
#  32     23463            SERDAR YAZICI                      50         NaN
#  33     23460         SERHAT ÇETİNKAYA                      32         NaN
#  34     23194               SEYDİ SARI                      38         NaN
#  35     23473            ŞAHİN TAŞKAYA                      46         NaN
#  36     23580                ŞEYDA ÖRS                      50         NaN
#  37     23197                TANER HAN                      50         NaN
#  38     23454          TANER HANIMOĞLU                      36         NaN
#  39     23461          TARIK YİĞİTBAŞI                      50         NaN
#  40     23273              TUĞÇE DOĞAN                      38         NaN
#  41     23134              EMRAH KÜÇÜK                       0         NaN
#  42     23135           FETHİYE YILMAZ                       0         NaN
#  43     23272             ÇETİN ÇELEBİ                       0         NaN
#  44     23332        ALİ İHSAN DESTİCİ                       0         NaN
#  45     23449   MUHAMMET LÜTFİ BAŞBOĞA                       0         NaN
#  46     23582                 ALİ DOST                       0         NaN
#  47     23587                 OKAN GÖK                       0         NaN
#  48     23588              TURGAY KAYA                       0         NaN
#  49     23472            İBRAHİM YAŞAR                       0         NaN
#  50     23340                 ALİ İĞDE                       0         NaN
#  51     19781               ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 51 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      46         NaN
#  3      23457               AYSU YILDIRIM                      48         NaN
#  4      23570              BAVER AYYILDIZ                      44         NaN
#  5      23469                  BULUT AZAK                      30         NaN
#  6      23596            CEMAL CAN ARSLAN                      42         NaN
#  7      23471                DİLAN ERTUNÇ                      40         NaN
#  8      23459                 ENGİN AYVAT                      48         NaN
#  9      23198                 ERDAL ŞAHAN                      48         NaN
#  10     23458              ERTUĞRUL AYDIN                      48         NaN
#  11     23455                FADİME SAÇAR                      44         NaN
#  12     23450                  FARUK OKAY                      46         NaN
#  13     23193             FATİH KARADİKEN                      28         NaN
#  14     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      42         NaN
#  15     23462               HAKAN ERTİNGÜ                      46         NaN
#  16     23139         HÜSEYİN KEVENCİOĞLU                      18         NaN
#  17     23472               İBRAHİM YAŞAR                      24         NaN
#  18     23456                 İSHAK ÖZBEK                      40         NaN
#  19     23448           KAAN MAHMUT MACAR                      48         NaN
#  20     20676                KEZBAN CANER                      30         NaN
#  21     23196                 KÜBRA GÖKÇE                      46         NaN
#  22     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      32         NaN
#  23     23467               MERVE NUR KUŞ                      44         NaN
#  24     23465                MESUT TEKELİ                      46         NaN
#  25     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  26     23581         MUHAMMET EMİN KESİK                      48         NaN
#  27     23330          MUHAMMET KARADUMAN                      42         NaN
#  28     23449      MUHAMMET LÜTFİ BAŞBOĞA                      14         NaN
#  29     23138           MUHAMMET YILDIRIM                      18         NaN
#  30     23464               MUKADDER KENT                      48         NaN
#  31     23452            MUSA OZAN PATACI                      48         NaN
#  32     23136                 OKTAY AYANA                      46         NaN
#  33     23453               ÖMER BOSTANCI                      44         NaN
#  34     23195               ÖMER YILDIRIM                      48         NaN
#  35     23132                 ÖZCAN ÇAKIR                      48         NaN
#  36     23463               SERDAR YAZICI                      48         NaN
#  37     23460            SERHAT ÇETİNKAYA                      48         NaN
#  38     23194                  SEYDİ SARI                      48         NaN
#  39     23473               ŞAHİN TAŞKAYA                      40         NaN
#  40     23580                   ŞEYDA ÖRS                      36         NaN
#  41     23197                   TANER HAN                      48         NaN
#  42     23454             TANER HANIMOĞLU                      42         NaN
#  43     23461             TARIK YİĞİTBAŞI                      48         NaN
#  44     23273                 TUĞÇE DOĞAN                      42         NaN
#  45     23134                 EMRAH KÜÇÜK                       0         NaN
#  46     23135              FETHİYE YILMAZ                       0         NaN
#  47     23272                ÇETİN ÇELEBİ                       0         NaN
#  48     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 30 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      48         NaN
#  1      23582                    ALİ DOST                      48         NaN
#  2      23451                AYLİN YILDIZ                      48         NaN
#  3      23570              BAVER AYYILDIZ                      48         NaN
#  4      23469                  BULUT AZAK                      44         NaN
#  5      23596            CEMAL CAN ARSLAN                      44         NaN
#  6      23471                DİLAN ERTUNÇ                      38         NaN
#  7      23459                 ENGİN AYVAT                      48         NaN
#  8      23198                 ERDAL ŞAHAN                      48         NaN
#  9      23458              ERTUĞRUL AYDIN                      48         NaN
#  10     23455                FADİME SAÇAR                      48         NaN
#  11     23450                  FARUK OKAY                      48         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      48         NaN
#  14     23462               HAKAN ERTİNGÜ                      48         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      48         NaN
#  16     23472               İBRAHİM YAŞAR                      32         NaN
#  17     23456                 İSHAK ÖZBEK                      48         NaN
#  18     23448           KAAN MAHMUT MACAR                      48         NaN
#  19     20676                KEZBAN CANER                      48         NaN
#  20     23196                 KÜBRA GÖKÇE                      48         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      48         NaN
#  22     23467               MERVE NUR KUŞ                      48         NaN
#  23     23465                MESUT TEKELİ                      44         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      48         NaN
#  25     23581         MUHAMMET EMİN KESİK                      48         NaN
#  26     23330          MUHAMMET KARADUMAN                      40         NaN
#  27     23449      MUHAMMET LÜTFİ BAŞBOĞA                      48         NaN
#  28     23138           MUHAMMET YILDIRIM                      48         NaN
#  29     23464               MUKADDER KENT                      48         NaN
#  30     23452            MUSA OZAN PATACI                      48         NaN
#  31     23136                 OKTAY AYANA                      40         NaN
#  32     23453               ÖMER BOSTANCI                      48         NaN
#  33     23195               ÖMER YILDIRIM                      48         NaN
#  34     23132                 ÖZCAN ÇAKIR                      48         NaN
#  35     23463               SERDAR YAZICI                      48         NaN
#  36     23460            SERHAT ÇETİNKAYA                      48         NaN
#  37     23194                  SEYDİ SARI                      44         NaN
#  38     23473               ŞAHİN TAŞKAYA                      40         NaN
#  39     23580                   ŞEYDA ÖRS                      48         NaN
#  40     23197                   TANER HAN                      48         NaN
#  41     23454             TANER HANIMOĞLU                      42         NaN
#  42     23461             TARIK YİĞİTBAŞI                      48         NaN
#  43     23273                 TUĞÇE DOĞAN                      48         NaN
#  44     23134                 EMRAH KÜÇÜK                       0         NaN
#  45     23135              FETHİYE YILMAZ                       0         NaN
#  46     23272                ÇETİN ÇELEBİ                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 49 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#      Sicil No                    Ad Soyad  Oturum Süresi (Dakika)  Unnamed: 3  \
#  0      23466              ABDULLAH ASLAN                      42         NaN
#  1      23582                    ALİ DOST                      42         NaN
#  2      23451                AYLİN YILDIZ                      42         NaN
#  3      23570              BAVER AYYILDIZ                      42         NaN
#  4      23469                  BULUT AZAK                      34         NaN
#  5      23596            CEMAL CAN ARSLAN                      38         NaN
#  6      23471                DİLAN ERTUNÇ                      42         NaN
#  7      23459                 ENGİN AYVAT                      42         NaN
#  8      23198                 ERDAL ŞAHAN                      24         NaN
#  9      23458              ERTUĞRUL AYDIN                      42         NaN
#  10     23455                FADİME SAÇAR                      42         NaN
#  11     23450                  FARUK OKAY                      42         NaN
#  12     23193             FATİH KARADİKEN                      32         NaN
#  13     23468     GÜRHAN MUSTAFA ÇINARBAŞ                      38         NaN
#  14     23462               HAKAN ERTİNGÜ                      42         NaN
#  15     23139         HÜSEYİN KEVENCİOĞLU                      42         NaN
#  16     23472               İBRAHİM YAŞAR                      14         NaN
#  17     23456                 İSHAK ÖZBEK                      42         NaN
#  18     23448           KAAN MAHMUT MACAR                      42         NaN
#  19     20676                KEZBAN CANER                      42         NaN
#  20     23196                 KÜBRA GÖKÇE                      42         NaN
#  21     11048  MEHTAP FULYA ÖZKELEŞ İYBAR                      30         NaN
#  22     23467               MERVE NUR KUŞ                      42         NaN
#  23     23465                MESUT TEKELİ                      36         NaN
#  24     23470          MİRZA MEHMET YÜCEL                      42         NaN
#  25     23581         MUHAMMET EMİN KESİK                      42         NaN
#  26     23449      MUHAMMET LÜTFİ BAŞBOĞA                      38         NaN
#  27     23138           MUHAMMET YILDIRIM                      42         NaN
#  28     23464               MUKADDER KENT                      42         NaN
#  29     23452            MUSA OZAN PATACI                      42         NaN
#  30     23136                 OKTAY AYANA                      42         NaN
#  31     23453               ÖMER BOSTANCI                      34         NaN
#  32     23195               ÖMER YILDIRIM                      42         NaN
#  33     23132                 ÖZCAN ÇAKIR                      42         NaN
#  34     23463               SERDAR YAZICI                      42         NaN
#  35     23460            SERHAT ÇETİNKAYA                      42         NaN
#  36     23194                  SEYDİ SARI                      42         NaN
#  37     23473               ŞAHİN TAŞKAYA                      34         NaN
#  38     23580                   ŞEYDA ÖRS                      42         NaN
#  39     23197                   TANER HAN                      42         NaN
#  40     23454             TANER HANIMOĞLU                      12         NaN
#  41     23461             TARIK YİĞİTBAŞI                      42         NaN
#  42     23273                 TUĞÇE DOĞAN                      42         NaN
#  43     23134                 EMRAH KÜÇÜK                       0         NaN
#  44     23135              FETHİYE YILMAZ                       0         NaN
#  45     23272                ÇETİN ÇELEBİ                       0         NaN
#  46     23330          MUHAMMET KARADUMAN                       0         NaN
#  47     23332           ALİ İHSAN DESTİCİ                       0         NaN
#  48     23457               AYSU YILDIRIM                       0         NaN
#  49     23587                    OKAN GÖK                       0         NaN
#  50     23588                 TURGAY KAYA                       0         NaN
#  51     23340                    ALİ İĞDE                       0         NaN
#  52     19781                  ALİ DÜNDAR                       0         NaN
#
#              Unnamed: 4
#  0   DERS SÜRESİ 43 DK.
#  1                  NaN
#  2                  NaN
#  3                  NaN
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                  NaN
#  8                  NaN
#  9                  NaN
#  10                 NaN
#  11                 NaN
#  12                 NaN
#  13                 NaN
#  14                 NaN
#  15                 NaN
#  16                 NaN
#  17                 NaN
#  18                 NaN
#  19                 NaN
#  20                 NaN
#  21                 NaN
#  22                 NaN
#  23                 NaN
#  24                 NaN
#  25                 NaN
#  26                 NaN
#  27                 NaN
#  28                 NaN
#  29                 NaN
#  30                 NaN
#  31                 NaN
#  32                 NaN
#  33                 NaN
#  34                 NaN
#  35                 NaN
#  36                 NaN
#  37                 NaN
#  38                 NaN
#  39                 NaN
#  40                 NaN
#  41                 NaN
#  42                 NaN
#  43                 NaN
#  44                 NaN
#  45                 NaN
#  46                 NaN
#  47                 NaN
#  48                 NaN
#  49                 NaN
#  50                 NaN
#  51                 NaN
#  52                 NaN  ,
#  Empty DataFrame
#  Columns: []
#  Index: []]

# %%
summed_sessions = dfs.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 summed_sessions = dfs.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
type(dfs)
# Out:
# list

# %%
merged_df = pd.concat(dfs, ignore_index=True)

# %%
summed_sessions = merged_df.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0      11048                     110
# 1      19031                     154
# 2      19781                       0
# 3      20676                     120
# 4      23132                     288
# 5      23134                       0
# 6      23135                       0
# 7      23136                     274
# 8      23138                     258
# 9      23139                     236
# 10     23193                     242
# 11     23194                     276
# 12     23195                     292
# 13     23196                     290
# 14     23197                     292
# 15     23198                     206
# 16     23272                       0
# 17     23273                     274
# 18     23330                     208
# 19     23332                       0
# 20     23340                       0
# 21     23448                     292
# 22     23449                     168
# 23     23450                     280
# 24     23451                     290
# 25     23452                     292
# 26     23453                     238
# 27     23454                     224
# 28     23455                     288
# 29     23456                     280
# 30     23457                     202
# 31     23458                     288
# 32     23459                     292
# 33     23460                     274
# 34     23461                     292
# 35     23462                     290
# 36     23463                     292
# 37     23464                     292
# 38     23465                     266
# 39     23466                     288
# 40     23467                     288
# 41     23468                     282
# 42     23469                     232
# 43     23470                     234
# 44     23471                     262
# 45     23472                     110
# 46     23473                     232
# 47     23570                     266
# 48     23580                     280
# 49     23581                     292
# 50     23582                     230
# 51     23587                       0
# 52     23588                       0
# 53     23596                     260

# %%
excel_file_2 =r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 22 MART 2024 YOKLAMALARI.xlsx"
xl2 = pd.ExcelFile(excel_file_2)

# %%
dfs2 = []
for sheet_name in xl2.sheet_names:
    df2 = pd.read_excel(excel_file_2, sheet_name=sheet_name)
    dfs2.append(df2)

# %%
merged_df2=pd.concat(dfs2, ignore_index=True)

# %%
summed_sessions2 = merged_df2.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions2
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0      13285                      46
# 1      17351                      52
# 2      17359                      20
# 3      17691                      32
# 4      18212                      30
# ..       ...                     ...
# 56     23581                     280
# 57     23582                       0
# 58     23587                       0
# 59     23588                       0
# 60     23596                     236
#
# [61 rows x 2 columns]

# %%
excel_file_1 =r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 21 MART 2024 YOKLAMALARI.xlsx"
xl1 = pd.ExcelFile(excel_file_1)

# %%
dfs1 = []
for sheet_name in xl1.sheet_names:
    df1 = pd.read_excel(excel_file_1, sheet_name=sheet_name)
    dfs1.append(df1)

# %%
merged_df1=pd.concat(dfs1, ignore_index=True)

# %%
summed_sessions1 = merged_df1.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions1
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0      11048                     110
# 1      19031                     154
# 2      19781                       0
# 3      20676                     120
# 4      23132                     288
# 5      23134                       0
# 6      23135                       0
# 7      23136                     274
# 8      23138                     258
# 9      23139                     236
# 10     23193                     242
# 11     23194                     276
# 12     23195                     292
# 13     23196                     290
# 14     23197                     292
# 15     23198                     206
# 16     23272                       0
# 17     23273                     274
# 18     23330                     208
# 19     23332                       0
# 20     23340                       0
# 21     23448                     292
# 22     23449                     168
# 23     23450                     280
# 24     23451                     290
# 25     23452                     292
# 26     23453                     238
# 27     23454                     224
# 28     23455                     288
# 29     23456                     280
# 30     23457                     202
# 31     23458                     288
# 32     23459                     292
# 33     23460                     274
# 34     23461                     292
# 35     23462                     290
# 36     23463                     292
# 37     23464                     292
# 38     23465                     266
# 39     23466                     288
# 40     23467                     288
# 41     23468                     282
# 42     23469                     232
# 43     23470                     234
# 44     23471                     262
# 45     23472                     110
# 46     23473                     232
# 47     23570                     266
# 48     23580                     280
# 49     23581                     292
# 50     23582                     230
# 51     23587                       0
# 52     23588                       0
# 53     23596                     260

# %%
excel_file_3 =r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 20 MART 2024 YOKLAMALARI.xlsx"
xl3 = pd.ExcelFile(excel_file_3)

# %%
dfs3 = []
for sheet_name in xl3.sheet_names:
    df3 = pd.read_excel(excel_file_3, sheet_name=sheet_name)
    dfs3.append(df3)

# %%
merged_df3=pd.concat(dfs3, ignore_index=True)

# %%
summed_sessions3 = merged_df3.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions3
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0      19031                     280
# 1      19781                     296
# 2      23132                     280
# 3      23134                       0
# 4      23135                       0
# 5      23136                     298
# 6      23138                     294
# 7      23139                     260
# 8      23193                     290
# 9      23194                     282
# 10     23195                     294
# 11     23196                     302
# 12     23197                     302
# 13     23198                     202
# 14     23272                       0
# 15     23273                     274
# 16     23330                     260
# 17     23332                       0
# 18     23340                       0
# 19     23448                     300
# 20     23449                     170
# 21     23450                     298
# 22     23451                     298
# 23     23452                     298
# 24     23453                     278
# 25     23454                     274
# 26     23455                     302
# 27     23456                     294
# 28     23457                     302
# 29     23458                     276
# 30     23459                     302
# 31     23460                     292
# 32     23461                     300
# 33     23462                     296
# 34     23463                     302
# 35     23464                     302
# 36     23465                     296
# 37     23466                     300
# 38     23467                     296
# 39     23468                     286
# 40     23469                     286
# 41     23470                     290
# 42     23471                     268
# 43     23472                       0
# 44     23473                     260
# 45     23570                     242
# 46     23580                     298
# 47     23581                     258
# 48     23582                     180
# 49     23587                       0
# 50     23588                       0
# 51     23596                     260

# %%
excel_file_4 =r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 19 MART 2024 YOKLAMALARI.xlsx"
xl4 = pd.ExcelFile(excel_file_4)

# %%
dfs4 = []
for sheet_name in xl4.sheet_names:
    df4 = pd.read_excel(excel_file_4, sheet_name=sheet_name)
    dfs4.append(df4)

# %%
merged_df4=pd.concat(dfs4, ignore_index=True)

# %%
summed_sessions4 = merged_df4.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions4
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0       7873                     134
# 1      15807                      58
# 2      16554                     160
# 3      19632                     152
# 4      21563                       0
# 5      23132                     322
# 6      23134                       0
# 7      23135                       0
# 8      23136                     308
# 9      23138                     322
# 10     23139                     298
# 11     23193                     282
# 12     23194                     328
# 13     23195                     300
# 14     23196                     322
# 15     23197                     328
# 16     23198                     150
# 17     23272                       0
# 18     23273                     312
# 19     23330                     276
# 20     23332                       0
# 21     23340                       0
# 22     23448                     322
# 23     23449                     242
# 24     23450                     254
# 25     23451                     314
# 26     23452                     322
# 27     23453                     256
# 28     23454                     280
# 29     23455                     326
# 30     23456                     298
# 31     23457                     318
# 32     23458                     316
# 33     23459                     328
# 34     23460                     278
# 35     23461                     326
# 36     23462                     298
# 37     23463                     300
# 38     23464                     328
# 39     23465                     318
# 40     23466                     320
# 41     23467                     328
# 42     23468                     308
# 43     23469                     274
# 44     23470                     234
# 45     23471                     292
# 46     23472                       0
# 47     23473                     238
# 48     23570                     326
# 49     23580                     308
# 50     23581                     316
# 51     23582                     114
# 52     23587                       0
# 53     23588                       0
# 54     23596                     310

# %%
excel_file_5 =r"C:\Users\90506\Desktop\ORYANTASYON EĞİTİMİ - 18 MART 2024 YOKLAMALARI.xlsx"
xl5 = pd.ExcelFile(excel_file_5)

# %%
dfs5 = []
for sheet_name in xl5.sheet_names:
    df5 = pd.read_excel(excel_file_5, sheet_name=sheet_name)
    dfs5.append(df5)

# %%
merged_df5=pd.concat(dfs5, ignore_index=True)

# %%
summed_sessions5 = merged_df5.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions5
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0      13554                     152
# 1      19031                       0
# 2      19781                       0
# 3      20331                     150
# 4      20902                      30
# 5      23132                     278
# 6      23134                       0
# 7      23135                       0
# 8      23136                     278
# 9      23138                     287
# 10     23139                     250
# 11     23193                     154
# 12     23194                     303
# 13     23195                     303
# 14     23196                     296
# 15     23197                     303
# 16     23198                     278
# 17     23272                       0
# 18     23273                     282
# 19     23330                     292
# 20     23332                       0
# 21     23340                       0
# 22     23448                     302
# 23     23449                     272
# 24     23450                     282
# 25     23451                     302
# 26     23452                     299
# 27     23453                     292
# 28     23454                     288
# 29     23455                     302
# 30     23456                     266
# 31     23457                     274
# 32     23458                       0
# 33     23459                     278
# 34     23460                     278
# 35     23461                     302
# 36     23462                     293
# 37     23463                     302
# 38     23464                     282
# 39     23465                      94
# 40     23466                       0
# 41     23467                     303
# 42     23468                     288
# 43     23469                     274
# 44     23470                     256
# 45     23471                     276
# 46     23472                       0
# 47     23473                     262
# 48     23570                       0
# 49     23580                     294
# 50     23581                     298
# 51     23582                     218
# 52     23587                      88
# 53     23588                       0
# 54     23596                     282

# %%
output_excel1=r"C:\Users\90506\Desktop\21martnew.xlsx"

# %%
summed_sessions1.to_excel(output_excel1,index=False)

# %%
output_excel1
# Out:
# 'C:\\Users\\90506\\Desktop\\21martnew.xlsx'

# %%
output_excel2=r"C:\Users\90506\Desktop\22martnew.xlsx"

# %%
summed_sessions2.to_excel(output_excel2,index=False)

# %%
output_excel3=r"C:\Users\90506\Desktop\20martnew.xlsx"

# %%
summed_sessions3.to_excel(output_excel3,index=False)

# %%
output_excel4=r"C:\Users\90506\Desktop\19martnew.xlsx"

# %%
summed_sessions4.to_excel(output_excel4,index=False)

# %%
output_excel5=r"C:\Users\90506\Desktop\18martnew.xlsx"

# %%
summed_sessions5.to_excel(output_excel5,index=False)

# %%
output_excel5
# Out:
# 'C:\\Users\\90506\\Desktop\\18martnew.xlsx'

# %%
278*70/100
# Out:
# 194.6

# %%
merged_df = pd.read_excel(excel_files[0])

# %%
file_paths = [
    r"C:\Users\90506\Desktop\18martnew.xlsx",
    r"C:\Users\90506\Desktop\19martnew.xlsx",
    r"C:\Users\90506\Desktop\20martnew.xlsx",
    r"C:\Users\90506\Desktop\21martnew.xlsx",
    r"C:\Users\90506\Desktop\22martnew.xlsx"
]

# %%
all_data=[]

# %%
for file_path in file_paths:
    xls = pd.ExcelFile(file_path)
    for sheet_name in xls.sheet_names:
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        all_data.append(df)

# %%
merged_df = pd.concat(all_data, ignore_index=True)

# %%
summed_sessions = merged_df.groupby('Sicil No')['Oturum Süresi (Dakika)'].sum().reset_index()

# %%
summed_sessions
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0       7873                     134
# 1      11048                     110
# 2      13285                      46
# 3      13554                     152
# 4      15807                      58
# ..       ...                     ...
# 67     23581                    1444
# 68     23582                     742
# 69     23587                      88
# 70     23588                       0
# 71     23596                    1348
#
# [72 rows x 2 columns]

# %%
output_excel = r"C:\Users\90506\Desktop\alldata.xlsx"

# %%
output_excel
# Out:
# 'C:\\Users\\90506\\Desktop\\alldata.xlsx'

# %%
summed_sessions.to_excel(output_excel, index=False)

# %%
summed_sessions
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0       7873                     134
# 1      11048                     110
# 2      13285                      46
# 3      13554                     152
# 4      15807                      58
# ..       ...                     ...
# 67     23581                    1444
# 68     23582                     742
# 69     23587                      88
# 70     23588                       0
# 71     23596                    1348
#
# [72 rows x 2 columns]

# %%
1457*70/100
# Out:
# 1019.9

# %%
threshold = 1457 * 0.7

# %%
filtered_sessions = summed_sessions[summed_sessions['Oturum Süresi (Dakika)'] < threshold]

# %%
filtered_sessions
# Out:
#     Sicil No  Oturum Süresi (Dakika)
# 0       7873                     134
# 1      11048                     110
# 2      13285                      46
# 3      13554                     152
# 4      15807                      58
# 5      16554                     160
# 6      17351                      52
# 7      17359                      20
# 8      17691                      32
# 9      18212                      30
# 10     19031                     434
# 11     19033                      52
# 12     19632                     152
# 13     19781                     296
# 14     20027                      52
# 15     20331                     150
# 16     20499                      36
# 17     20676                     120
# 18     20898                      52
# 19     20902                      30
# 20     21258                      46
# 21     21563                      30
# 23     23134                       0
# 24     23135                       0
# 34     23272                       0
# 37     23332                       0
# 38     23340                       0
# 40     23449                    1016
# 63     23472                     110
# 68     23582                     742
# 69     23587                      88
# 70     23588                       0

# %%
kalanlar_excel=r"C:\Users\90506\Desktop\kalanlar.xlsx"

# %%
kalanlar.to_excel(kalanlar_excel,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 kalanlar.to_excel(kalanlar_excel,index=False)
#
# NameError: name 'kalanlar' is not defined

# %%
kalanlar_excel
# Out:
# 'C:\\Users\\90506\\Desktop\\kalanlar.xlsx'

# %%
filtered_sessions.to_excel(kalanlar_excel,index=False)
